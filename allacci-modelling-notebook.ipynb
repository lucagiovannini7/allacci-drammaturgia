# %% [markdown]
# #Modelling and exploring Leone Allacci's _Drammaturgia_
#
# Code and data for a submission to AIUCD 2024.

# %% [markdown]
# ## 1. Modellation

# %%
import pandas as pd
import requests
import re
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium.plugins import HeatMap

# %% [markdown]
# ### Information retrieval

# %% [markdown]
# #### Title

# %%
def extract_title(sentence):
    # Find the first element in the sentence up to the full stop
    match = re.search(r'[^.]*\.', sentence)

    if match:
        # Extract the matched text
        matched_text = match.group().strip(".")

        # Check for the presence of "ovvero" or "o sia"
        if "ovvero" in matched_text or "o sia" in matched_text:
            # Split the text into title and subtitle
            title, _, subtitle = re.split(r'\s*(ovvero|o sia)\s*', matched_text, maxsplit=1)
            title = title.strip()
            subtitle = subtitle.strip()
            return title.title(), subtitle.title()
        else:
            # If "ovvero" or "o sia" is not present, set subtitle_one to None
            title = matched_text.strip()
            return title.title(), None
    else:
        return None, None

# %%
# test
test = "SUPERBIA ABBATTUTA NEL TRIONFO DI ESTER. — in Roma, per il Buagni, 1706 in 12 — cogli altri Drammi dell'Autore. — di Arcangelo Spagna. "
extract_title(test)
# Out:
# ('Superbia Abbattuta Nel Trionfo Di Ester', None)

# %% [markdown]
# #### Genre

# %%
def extract_genre(sentence):
    # Find the first full stop in the sentence
    first_full_stop_match = re.search(r'(?<!\b[SIVX])\.', sentence)

    if first_full_stop_match:
        # Find the second full stop or a parenthesis in the remaining text
        second_full_stop_match = re.search(r'\.|\(', sentence[first_full_stop_match.end():])

        if second_full_stop_match:
            # Extract text from the first full stop to the second full stop
            text_after_full_stop = sentence[first_full_stop_match.end():first_full_stop_match.end() + second_full_stop_match.end()]

            # Handle exception for:
            if "— in" in text_after_full_stop:
                return "Unknown"
            elif "Dramma rappresentato" in text_after_full_stop or "Dramma recitato" in text_after_full_stop:
                return "Dramma"

            genre = text_after_full_stop.strip().strip(".|(")

            # Keep only the first two words of the genre
            genre_words = genre.split()
            genre = ' '.join(genre_words[:2])
            genre = genre.replace(" di","")
            genre = genre.replace(" per","")
            genre = genre.strip()

            return genre
    else:
        return None

# %%
# test
test = "ACCOPPIO ARMONICO DI I. CECILIA CON S. FILIPPO NERI. Tragedia di cantato la Sera, in cui ricorse la Festa della medesima Santa, e si aprì il nuovo Oratorio di esso in Perugia l'anno 1689. Dedicato a Monsign. Illustrissimo, e Reverendiss. Luc'Alberto Patrizi, Vescovo di essa Città. — in Perugia per il Costantini. 1689 in 4 — Poesia d'incerto Autore"
extract_genre(test)
# Out:
# 'Tragedia'

# %% [markdown]
# #### Mode

# %%
def extract_mode(entry):
    mode = None

    if 'prosa' in entry.lower():
        mode = 'prose'
    elif 'versi' in entry.lower() or 'ottava rima' in entry.lower():
        mode = 'verse'

    return mode

# %% [markdown]
# #### Location

# %%
def extract_location(entry):

    # check for "Senza luogo" outside the loop
    if "senza luogo" in entry:
        return "Unknown"

    # let's temporarily remove expressions which confuse the parser

    strings = ["in prosa", "in versi", "in due", "in quattro",
               "in ottava", "in terza", "in terzine", "in forma",
               "in luce", "in atto", "in cinque", "in musica",
               "in Musica", "in occasione", "in verso", "in lingua",
               "in Lingua", "in tre", "in Amore", "in data", "in una",
               "in Italiano", "in terzetti", "in Atti", "in S.",
               "in Casa", "in applauso", "in un", "in cui", "in onore",
               "recitato in", "rappresentato in"]  # we remove also what points to staging location
    for string in strings:
      if string in entry:
        entry = entry.replace(string, "")

    # remove uppercase words
    entry = re.sub(r'IN [A-Z]+', '', entry)

    location_pattern = re.compile(r'(?i)in\s([^\s\d]+)')
    match = location_pattern.search(entry)

    location = match.group(1) if match else None
    if location:
      location = location.strip(",")
      location = location.strip(".")
      if location in ["Ven", "Venez","Vinegia"]:
        location = "Venezia"
      if "." in location:
        location.replace(".","")
    return location

# %%
test = "ACCIDENTI DEL VITTORIOSO GOFFREDO IN SORTE. Scenario. — in Bologna.,"
extract_location(test)
# Out:
# 'Bologna'

# %% [markdown]
# ####Publisher

# %%
def extract_publisher(entry):

    # Let's temporarily remove misdirections from the entry
    strings = ["per Musica","per comando", "di Personaggi"]
    for string in strings:
      if string in entry:
        entry = entry.replace(string, "")

    # Check for "Senza Stampatore" outside the loop
    if "senza Stampatore" in entry or "senza nome di Stampatore" in entry :
        return "Unknown"
    if "e Stampatore" in entry or ", Stampatore" in entry :
        return "Unknown"

    # Define sets of publisher expressions within the function
    pointer_sets = [
        ("per il", "per gli", "presso il", "presso gli", "nella Stamperia del"),
        ("per", "pel", "presso", "appr\.", "nella Stamperia", "nella Stampa", "appresso"),
        ("ad istanza", "all'Insegna")
    ]

    # Iterate through each set of pointers
    for pub_pointers in pointer_sets:
        # Combine the current set of pointers into a regex pattern
        pub_pattern_str = '|'.join(pub_pointers)
        publisher_pattern = re.compile(fr'(?i)\b(?:{pub_pattern_str})\s*([^.,]+)[.,]')

        # Use the regex pattern to search for a match in the input string
        match = publisher_pattern.search(entry)

        # If a match is found, extract and return the publisher information
        if match:
            if "Gio." in match.group(0):
                # Take the following two words as the publisher
                publisher_words = re.findall(r'\b\w+\b', entry)
                publisher_index = publisher_words.index("Gio") + 1
                return ' '.join(publisher_words[publisher_index: publisher_index + 2])
            else:
                # Extract and return the publisher information
                publisher = match.group(1).strip()
                if publisher == "Pietro Van":
                  publisher = "Pietro Van Ghelen"
                if publisher == "Niccolini":
                  publisher = "Francesco Niccolini"
                return publisher

    # If no match is found in any set of pointers, return None
    return None

# %%
test = "ABEL. Orazione Sacra per Musica. senza Nome, per Pietro Van Ghelen."
extract_publisher(test)
# Out:
# 'Pietro Van Ghelen'

# %% [markdown]
# ####Year

# %%
def extract_year(entry):

    # check for "Senza anno" outside the loop
    if "senz'anno" in entry.lower() or "senza anno" in entry.lower() or "re, ed anno" in entry.lower():
        return "Unknown"

    # Define the pattern for finding the year followed by "in"
    year_pattern = re.compile(r'(\d{4})\s*in', re.IGNORECASE)

    # Search for the pattern in the input string
    match = year_pattern.search(entry)

    # If the pattern is found, return the matched year
    if match:
        year = int(match.group(1))
        return year
    else:
        # If the pattern is not found, try finding any year pattern
        general_year_pattern = re.compile(r'(\d{4})')
        general_match = general_year_pattern.search(entry)
        general_year = int(general_match.group(1)) if general_match else None
        return general_year

# %%
test = "ALARICO RE DE' GOTI. Dramma recitato in Ferrara 1876. nel Teatro Bonacossi. senza Stampatore"
extract_year(test)
# Out:
# 1876

# %% [markdown]
# ####Format

# %%
def extract_format(entry):
    format_pattern = re.compile(r'in\s(\d+)')
    match = format_pattern.search(entry)
    format = match.group(1) if match else None
    return format

# %%
test = "ALARICO. Drama rappresentato nel Teatro Obizzi di Padova l'anno 1709 in Padova, senza Stampatore, 1709 in 12 — 1679 in 4 Poesia d'Incerto."
extract_format(test)
# Out:
# '12'

# %% [markdown]
# ####Author

# %%
def extract_author(entry):

    # Check for "incerto" outside the loop
    if "incerto au" in entry.lower() or "d'autore in" in entry.lower() or "d'incerto." in entry.lower():
        return "Unknown"

    # titles and honorifics to be removed later
    titles = ["Co. ","Conte ","Ab. ","Abate ", "P. ", "Padre",
              "Don ", "Dott. ", "Dottore ", "D. ", "Fra "]

    # Define the pattern for capturing two words after dash and "di" or "Poesia di"
    author_pattern = re.compile(r'(?:— di|— da|— del[l\']|— del|— dal|Poesia di|Poesia del)\s*([^,]+ [^,]+)')

    # Search for the pattern in the input string
    match = author_pattern.search(entry)

    # If the pattern is found, return the matched author
    if match:
        author = match.group(1).strip()
        # remove titles
        for title in titles:
          if title in author:
            author = author.replace(title, "")
        # fix residual issues
        if author.startswith("l'"):
            author = author.replace("l'", "")
        if author.startswith("'"):
            author = author.replace("'", "")
        if author.endswith("."):
          author = author.replace(".", "")
        if author.startswith("Polisseno Fegejo Pastor Arcade"):
                author = "Carlo Goldoni"
        return author
    else:
        return None

# %%
test = "ALARICO. Drama — del Co. Test Testi."
extract_author(test)
# Out:
# 'Test Testi'

# %% [markdown]
# ####Libretto

# %%
def check_if_libretto(entry):
    libretto = None

    if 'musica di' in entry.lower():
        libretto = True
    else:
        libretto = False

    return libretto

# %%
t = "Esampio di balb la Music di"
check_if_libretto(t)
# Out:
# False

# %% [markdown]
# ####Translation

# %%
def check_if_translation(entry):
    translation = None

    if 'tradot' in entry.lower() or "traduz" in entry.lower():
        translation = True
    else:
        translation = False

    return translation

# %% [markdown]
# ###Database building

# %%
url = 'https://raw.githubusercontent.com/lucagiovannini7/allacci-drammaturgia/main/allacci_da_pulire.txt'
response = requests.get(url).text
entries = response.split('\n')

# Create a DataFrame
df = pd.DataFrame({"entry": entries})

# %%
# extract info and fill the df

df['title'], df['subtitle'] = zip(*df['entry'].apply(extract_title))
df['author'] = df['entry'].apply(extract_author)
df['genre'] = df['entry'].apply(extract_genre)
df['mode'] = df['entry'].apply(extract_mode)
df['location'] = df['entry'].apply(extract_location)
df['publisher'] = df['entry'].apply(extract_publisher)
df['year'] = df['entry'].apply(extract_year)
df['format'] = df['entry'].apply(extract_format)
df['libretto'] = df['entry'].apply(check_if_libretto)
df['translation'] = df['entry'].apply(check_if_translation)

# Display the resulting DataFrame
#df.head(10)

# %% [markdown]
# #### Debug

# %%
# debug nones

none_entries = df.loc[df['author'].isnull(), 'entry']

for entry in none_entries:
    print(entry)
# Out:
# ACARNE. Commedia di Aristofane tradotta dal Greco in Lingua comun d'Italia. — in Vinegia, appr. Vincenzo Valgrisi. 1545 in 8 — di Bartolommeo, e Pietro Fratelli Rositini, da Pratalboino.
# ACCIDENTI D'AMORE. Commedia (in prosa). in Ven. appresso Angiol Salvadori. 1635. in 12. dal Dot. Fulvio Genga di Fano.
# ADAMIRA, ovvero, la Statua dell'Onore. Opera Scenica (in prosa). — in Ven. appr. Giacomo Batti. / 1657. in 12 — in Perugia, per Sebastian Zecchini, 1659. in 12 — in Venez. per il Pezzana 1662 in 12 — ed in Bologna, per Giacomo Monti. Senz'anno. in 12. E la stessa che l'Amore nella Statua, di Giacinto Andrea Cicognini, Fiorentino.
# ADARCONTE. Tragedia (in prosa). — in Roma, per Michiel Ercole. 1676.
# ADONE. Pastorale Drammatica. — in Napoli, per Tarquinio Longo. 1614. in 4. con le altre Poesie dell'Autore— Poesia di Marcello—Macedonio.
# ADRIANO. Tragedia di Giuseppe Squillaci, di Catania.
# ALBIDO. Favola Pastorale, — in Roma, per Giacomo Mascardi, 1624 in 12 — ed ivi, per Lodovico Grighani, 1646. in 8 — Poesia d'Ivo Gattula, Professore Primario di Legge nello Studio di Roma.
# ALCESTE DI EURIPIDE. Tragedia tradotta dal Pad. Carmeli M. O. — in Padova, per il Manfrè. 1747 in 8.
# ALERINDA, di Ercole Scala. in 12.
# ALESSANDRO MARTIRE TEBEO (S.). Tragedia, posta in scena all'Accademia de Pati in S. Maria Maddalena di Bergomo, — in Bergomo, per Valerio Ventura. 1619 in 8. — di Andrea, e Pietro Paste, Bergamaschi.
# ALESSANDRO. Commedia (in prosa) intitolata Alessandro di Alessandro Piccolomini Sanese, detto lo Stordito Accademico Intronato. Ven. per Agostino Bindoni in 8. — ivi per il Pietra Santa 1554 in 8 con altre quattro. — Senza luogo, Stampatore, e anno in 8 con due Prologhi non più impressi, e composti dal medesimo Autore per la prima, e la seconda volta, che fu recitata in Siena, — Venez. per il Rampazzetto. 1561 in 12 — ivi per il Giolito de Ferrari 1562 in 12 — ivi, per il Rampazzetto 1564 in 12 — ivi per il Salietto. 1569 in 12 — ivi per il Cavalcalupo 1584 in 12 — ivi per gli Eredi del Bonibello 1596 — in Siena, per il Florini 1612 in 12 — con tre altre degli Accademici Intronati di Siena, e due altre, del Piccolomini — Siena, per il Franceschi, 1611 in 12. con le altre cinque soprariferite in due Tomii, e sono. — nel primo Tomo Alessandro, Amor Costante, Ortensio del Piccolomini, Ingannati, degli Accademici Innati — Nel secondo Tomo Pellegrina di Girolamo Bargagli materiale Intronato, — gli Scambi dell'Aperto Intronato Belisai Bulgarini.
# ALESSANDRO IL GRANDE. Tragedia di M. Racine tradotta da Luisa Bergalli Veneziana — in Venezia, per il Lovisa. 1736 in 12, colle altre dello stesso.
# ALESSANDRO IL GRANDE. Tragedia di M. Racine tradotta da Incerto. — in Bologna, per il Volpe. 1724 in 12.
# ALZIRA. Tragedia di M. Voltaire tradotta dal Francese, da Incerto. — in Bologna, per il Volpe, 1738 in 4, e 1738 in 12.
# AMALASUNTA. di M. Quinault tradotta da Incerto — in Bologna, per il Volpe. 1724. in 12, con altre Op. tradotte dal Francese Tom. 3°.
# AMANTE FEDELE. Commedia (in prosa). — in Bologna, per Antonio Pisarri. senz'anno. in 12 — del Capriccioso.
# AMANTE NEMICA, ovvero, il Cid delle Spagne di Pietro Cornelio tradotta da Incerto. — in Bologna, pe il Volpe. 1724 in 12, con altre Op. tradotte dal Francese Tom. 39.
# AMANTI INGELOSITI. dell'Incognito Accademico Ozioso, cioè di Scipione Errico. — in Napoli, 1634 in 8.
# AMANTI MAGNIFICI. Commedia d M. Molier, tradotta (in prosa) di Nic. de Castelli. — Lipsia, per i Gleditsch 1698 in 12 —
# AMARANTA. Commedia Pastorale (in prosa). — in Viterbo, per i Discepoli. 1618 in 12 — ed in Roma, per Giacomo Mascardi, 1628 in 12 — di Gio, de Nobili, Romano.
# AMARANTA. Favola Boschereccia di Lucca Pastronicchi. — Milano, per il Timi, e il Lomazzo 1600 in 12.
# AMARILLI. Tragicommedia Pastorale di due Accademici d'Arcadia, cioè il Cardinale Albani, e l'Abate Filippo Fabri — 1704 in 8.
# AMMALATO IMMAGINARIO. Commedia di. M. Molier tradotta (in prosa). da Niccolò de Castelli. — Lipsia, per il Gleditsch. 1698 in 12, nel Tom. 4. dell'Opere di M. Molier in 4. Tomi.
# AMOR CASTIGATO. Dramma Musicale. — in Firenze, per il Bonardi. 1656 in 4 — Poena di Girolamo Bartolommei, già Smeducci, Fiorentino.
# AMOR E CIECO, ovvero, La Barberia. Commedia (in prosa) — in Bologna, per il Longhi. senz'anno. in 12.
# AMOR COSTANTE. Favola Boschereccia. — in Modona, per Gio. Maria Verdi. 1608 in 8 — Poesia Galvano Castaldi, Modonese.
# AMOR, E GRATITUDINE IN CIMENTO. Dramma rappresentato nel Teatro Dolfin di Trevigi. in Venez. per Carlo Buonarrigo, 1730 in 12 — AMOR INCOGNITO. Commedia. — Napoli, per Gio. Battista— Sottile. 1603 12 li Gio. de Grassis, da Minervino.
# AMOR MEDICO. Commedia di M. Molier trad. in prosa da Nicola de Castelli. — in Lipsia, per il Gleditsch. 1698 in 12, con tutte l'altre di M. Molier in tomi 4. questa e registrata nel Tom. 2.
# AMOR RITROSO. Tragedia di lieto fine recitata nel Teatro di Spoleti l'anno 1666. — in Macerata, per il Grisei, e Giuseppe Picino. 1666 in Poesia degli Accademici Oziosi di Spoleti, e Ottusi di Macerata.
# AMOR NON VUOL POLITICA. Commedia, in Bologna, per il Longhi. senz'anno in 12.
# AMOR TIRANNICO. Dramma recitato nel Teatro di S. Cassiano di Venezia l'anno 1710 — in Venezia, per Marino Rossetti. 1710 in 12.
# AMORE SCOLASTICO. Commedia, in Firenze, per Filippo Giunti, 1568 di Raffaello Martiar in 8, Fiorentino.
# AMORI INFRUTTUOSI DI PIRRO. Dramma recitato nel Teatro de' SS Gio. e Paolo di Venezia l'anno 1661 — in Venezia, per Francesco Niccolini, 1661 in 12 — Poesia Aurelio Aureli, Veneziano. — Musica di Antonio Sartorio, Veneziano.
# AMOROSA COSTANZA. Tragicommedia (in prosa) in Roma, pel Guglielmo Facciotti. 1629 in 12 — Francesco Antonio Flesca.
# AMOROSO SCAMPO. Commedia. — in Napoli, per il Carlino. 1613 e 1629 in 12 — d'Orazio Corcione, di Benevento.
# ANDRIENNE. Baccanale dedicato a S. E. la Sig. March. Marianne Pepoli Bentivoglio d'Aragona. — Senza luogo, e Stampatore. 1721. in 8 — d'un Accademico Intrepido, cioè, del Dott. Girolamo Baruffaldi, Ferrarese, Arciprete di Cento.
# ANDROMACA. Dramma per Musica. in Ferrara, per il Pomatelli in 12 — d'Incerto Antore.
# ANGELICA VINCITRICE D'ALCINA. Festa Teatrale rappresentata sopra Grande Peschiera dell'Imperiale Favorita, solennizzandosi la felicissima e gloriosa Nascita di Leopoldo Arciduca d'Austria, e Real—Principed Las Asturias, per comando della. C. e R. Catt. M. di Carlo VI. Imperad. dei Romani l'anno 1716. co fig. — in Vienna d'Austria per Gic Van Ghelen 1716 in 4 — Poesia Pietro Pariati, di Reggio di Modena. — Musica di Gian Gioseffo Fux Tedesco.
# ANIMA CON TUTTE LE SUE POTENZE ADORNATA DI TUTTE LE VIRTÙ APPARTENENTI A QUELLA, &c. Rappresentazione. — in Siena alla Loggia del Papa 1608 in 4
# ANNA RAPPRESENTATA, ovvero, La Grazia, e la Bellezza in Teatro guerreggianti, festeggianti, trionfanti. D.D.D. alla Sereniss. Madama Gran Duchessa di Toscana (in verso), del P. Diego Leguille, Accademico Sconosciuto, Teologo, e Predicatore Arciducale, in Ispruch, per Girolamo Agricola 1651 in 12 — Il P. Leguille Autore di quest'Opera era Napoletano, Riformato di S. Francesco, il quale nella Lettera Dedicatoria dice, che questi Comici passatempi veggono prima del Teatro il Cocchio di Germania. Il contenuto di questo Dramma è diviso in tre Prospettive, la prima, e la terza divisa in dieci, e la seconda in undici Apparati, con questo nome chiama gli Atti, e le Scene. Il soggetto di tutta l'Opera colle principali doti del Corpo presuppone le speziali dell'animo nella Serenissima Reggitrice de migliori Scettri di Germania. La Scena è in Ispruch, antica sede de Padroni della Contea del Tirolo, e Regia Arciducale de Regnanti Principi d'Austria. Dopo l'Opera si vede una spezie di Seconda parte col medesimo titolo, in cui si spiegano alcune cose relative a' Fatti accennati nella Poesia, ed a molte antiche erudizioni.
# ANNA (S.) Poema Drammatico. Francesco Garsia, di Palermo.
# ANTIGENIDE. Favola Musicale. — sen za luogo, Stampatore, ed anno. in 12 con le altre Poesie dell'Autore. — d Girolamo Bonsoni, di Rovigo.
# ANTIGONA IN TEBE. Opera Tragica (in prosa) tradotta dal Dramm. Musicale. — in Venezia, per Antonio Gislon. 1722 in 8. — Dalla invenzione di questa? cavata la Giocasta del Sig. Arciprete Girolamo Baruffaldi.
# APPARATO, E FESTE NELLE NOZZE DELL'ILLUSTRISS. SIGNOR DUCA DI FIRENZE CON LE SUE STANZE. Commedia, ed Intermedj in quella recitati, — in Firenze, per Benedetto Giunti. 1539 in 8 — ed ivi, per li Giunti, 1566 in 8 — La descrizione delle Feste è di Pier Francesco Giambullari. — Le stanze di Giambatista Gelli, Fiorentino. — la Commedia (in prosa) di Antonio Landi, intitolata, il Commodo. — E gl'intermezzi di Giambatista Strozzi.
# ARACINDA. Favola Pastorale — in Pisa, per Silvestro Marchetti, 1629 in 12 — d'Ilario Mancini.
# ARATO IN SPARTA. Dramma recitato nel teatro di Sant'Angiolo di Venezia l'anno 1709 — in Venezia, per Gambatista Zuccato, 1709 in 12 — Poesia Benedetto Marcello, Patrizio Veneto, per quanto si crede — musica di Giammaria Ruggieri Vneziano.
# ASTINOME. Dramma rappresentato nella Sala del Sig. Federico Capranica. — in Roma nella Stamperia del Bernabò. 1719 in 12 — Poesia d'un Accademico Quirino. — Musica di Carlo Francesco Pollaroli, Bresciano.
# ASTROLOGIA AMOROSA. Commedia (in prosa). in Vinegia, per gli Eredi di Altobello Salicato. 1650 in Domenico Raviccio, di Correggio, Accademico Scioperato detto l'Improvviso.
# ATALANTA. Commedia (in prosa) recitata anno 1610 dagli Accademici Sventati. — in Udine, per Pietro Lorio. 1610 in 12 — del Fiso, Accademico Sventato.
# ATAMANTE. Tragedia. — in Macerata, per Sebastiano Mantellini. 1579 in 4 — degli Accademici Catenati.
# ATRIANA INCOGNITA AMANTE. Commedia (in prosa) — in Chieti, per Ottavio Terzani. 1627 in 8 — Francesco Garbarino, di Atri. Da Toppi è detto Gasbarino.
# ATTALIA. Tragedia del Racine tradotta da D. Bonifazio Collina Ch. Reg. Som. in Bologna 1743 in 8.
# ATTALIA. Tragedia del Racine tradotta da Luisa Bergalli, Veneziana, tra gli Arcadi Irminda Partenide. — in Venezia per Domenico Lovisa. 1736 in 12 — Opere del Racine al T. 2.
# AULULARIA. Commedia di Plauto tradotta da Carlo Mariá Maggi, Milanese. — in Milano, per il Malatesta. 1711 in 12. Colle altre Poesie dell'Autore.
# AURORA. Favola Boschereccia (di vario metro) recitata in Siena, l'anno 1607 — in Siena, per Matteo Florini. 1608 in 4. del Dilettevole, cioè, Benvenuto Flori, Sanese, della Congrega de' Rozzi.
# BACCANTI. Commedia tradotta da M. Cristoforo Guidiccioni. — in Lucca, per il Benedini, 1747 in 8, Con altre 4 Tragedie tradotte dal detto.
# BAJAZET. Tragedia d. M. Racine, tradotta da Luisa Bergalli, Veneneziana. — in Venezia, per Domenico Lovisa. 1736 in 12, nel Tomo 2°. delle Opere del Racine tradotte dalla detta.
# BAJAZET. Tragedia di M. Racine tradotta da Incerto, col titolo però, di Rossane. — in Bologna, per IL Volpe. 1724 in 12 — nel Tom. 3°. delle Opere varie tradotte dal Francese.
# BARONA. Lamento pietoso del Disgraziato Clonico Pastore contra d'Amore, e di Delia crudele da lui sommamente amata (in ottava rima), — in Vinegia, per il Pencio da Lecco. 1528 in 8. Nel Frontispicio non si legge il titolo di Barona, ma solamente quello di Lamento, &c. Nell'argomento poi si dice. Incomincia la Barona composta per Sabba Castalio.
# BATECCHIO. Commedia nuova di Maggio (in terzine). — in Siena, per Francesco di Simeone ad instanza di Giovanni di Alessandro Libraro, del Mese di Febrajo MDXLVIIII in 8 — composta per il peregrin ingegno del Fumoso della Congrega de' Rozzi — di Siena, cioè, Silvestro Cartajo, Sanese. — È formata di nove Personaggi tra Pastori, Ninfe, e Villani, divisa in quattro Atti.
# BERENICE. Tragedia di M. Racine tradotta (in prosa) da Luisa Bergalli, Veneziana, — in Venezia, per Domenico Lovisa. 1736 in 12 — nel T. 20, dell'Opere del Racine tradotte dalla detta.
# BICCHIERE. Commedia (in terza rima) di Amore contra Avarizia, e Pudicizia, intitolata il Bicchiere. — in Siena ad istanza di Maestro Giovanni di Alessandro Cartajo nel 1544 in 8 — ed in Firenze, nel Garbo. 1573 in 4 — ed in Siena, senza nome di Stampatore, 1578 in 8 — composta per il peregrino ingegno di Mariano Maniscalco della Congrega de' Rozzi di Siena. — Era costui Maniscalco di Professione.
# BOSCHETTO. Dialogo allegro (in terzine). — in Siena, per Luca Bonetti. 1574 in 8 — ed ivi, senza Stampatore 1583 in 8 del Falotico della Congrega de' Rozzi, cioè, Gio. Battista Sarto, Sanese.
# BRITANNICO. Tragedia di M. Racine tradotta da Luisa Bergalli (in prosa). in Venezia, per Domenico Lovisa. 1736 in 12 — Nel Tom. I. delle Opere del Racine tradotte dalla detta.
# BRITANNICO. Tragedia di M. Racine tradotta da D. Francesco Giovanardi Prevosto di Modena. — in Ven. per Pietro Bassaglia. 1748 in 12.
# BRITANNICO. Tragedia di M. Racine tradotta dal P. Niccolò Avancino. in Milano, per il Vignone, e Fratelli. 1724 in 8.
# CACCIA DI DANAO. Tragisatiricommedia recitata in Padova sotto il Reggimento del Nob. Uomo Antonio Barbaro Capitanio di essa Città, l'anno 1614 — in Vicenza, per il Rizzardi, 1615 in 12 — di Antonio, Buzzacarino, Padovano.
# CACCO SCOPERTO. Dramma recitato alle sponde del delizioso Ravone nel Bolognese l'anno 1676 — Poesia dell'Assennato.
# CALZA GALLINA. Commedia nuova Rusticale, e ridicolosa (in terzine) nuovamente posta in luce. — in Siena adi 30 d'Ottobre, 1550 in & — ed ivi, alla Loggia del Papa. 1580 in 8 — di Strafalcione, della Congrega de' Rozzi di Siena, cioè, Ascanio Cacciaconti, Sanese.
# CANTATA recitata nel Palazza Apostolico la Notte del Santiss. Natale l'anno 1730 — in Roma, nella Stamperia della Rev. Camera. 1730 in 4 — Poesia, e Musica d'Incerti.
# CAPITOLO ALLA VILLANA (in terza rima) alla Padrona Sposa, la prima volta, che il Mezzajuolo la va a vedere. — Si truova stampato in Siena l'anno 1583 in 8 insieme con il Bruscello, e il Boschetto, Dialogbi allegri del Falotico. — del Fumoso, della Congrega de' Rozzi, cioè, Silvestro Cartajo, di Siena.
# CAPOTONDO. Commedia Rusticale (in terzine). — in Siena, per Francesco di Simeone ad istanza di Giovanni Librajo adi 24 di Ottob. 1550 in 8 — ed ivi, senza Stampatore. 1585 in 8 — composta per il peregrino Ingegno del Fumoso della Congrega de' Rozzi di Siena, cioè, Silvestro Cartajo, Sanese.
# CARATTACO. Componimento per Musica cantato nell'Accademia de' Signori Accademici Animosi di Venezia nel Palazzo di S. E. il Signor Gio. Carlo Grimani a' 12 di Decembre l'anno 1699 — in Venezia, senza Stampatore. 1699 in 4 — degli Accademici Animosi.
# CARCERATA NINFA. Favola Boschereccia. — in Mantova, per Aurelio, e Lodovico Osanna, Fratelli, 1618 in 4 — Poesia dell'Infuocato.
# CARNEVALE. Fabula Macaronea. — Bracciani, apud Andream Phæeum. 1620 in 8 — Poesia Andreæ Bajano, Latinæ Humanitatis, & Rethoricae Professoris Romae in Collegio Græeco.
# CASCATA DEGL'IDOLI NEL NASCIMENTO DEL REDENTORE. Rappresentazione Sacra. — in Napoli, per Carlo Troyse. 1701 in 12 — Baldassarre Pisani, Napoletano.
# CASIMIRO. Rappresentazione — in Napoli, per il Bulifon. 1686 in 12 — di Calcolone, cioè, Carlo Celano.
# CAVALIER BEVAGNA. Commedia (in prosa). — in Vienna d'Austria, per l'Heinger. 1726 in 8 — del Borosini.
# CAVALIERI. Commedia d'Aristofane tradotta dal Greco in Lingua comune d'Italia (in prosa). — in Venezia, per Vincenzo Valgrisi. 1545 in 8 — di Bartolommeo, e Pietro Rosittini Fratelli, da Pratalboino.
# CECARIA. Tragicommedia (di vario metro) intitulata Cecaria, nuovamente aggiuntovi un Lamento del Geloso con la Luminaria non più data in luce, con ogni diligentia revista, corretta, e ristampata. in Vinegia, per Niccolò d'Aristotile, detto Zoppino del Mese di Gennaro MDXXXV. in 8 — ivi, per Gio. Andrea Vavassore detto Guadagnino, e Florio Fratello. 1541 in 8 — ivi, per Francesco Rampazzetto, 1566 in 12 — ivi, per gli Eredi di Bartolommeo Rubini, 1586 in 12 — ed ivi, per Giambatista Bonfadino. 1594 in 12 — Poesia di Antonio, Epicuro, Napoletano. — Le quattro Edizioni segnate sono registrate dall'Allacci. Se ne vede poi un'altra col titolo seguente. — Dialogo di tre Ciechi, senza nome di Autore, e senza il Lamento del Geloso, e della Luminaria, — in Vinegia, per Gio. Antonio, e Fratelli da Sabbio. MDXXVI. in 8, cum gratia & privilegio dell'Illustriss. Signoria di Vinegia, che ditta Opera non si possa stampar fin anni X. sic come si contengono nel Breve (così stampato nel fine del Libro). — Qui sta pertanto pare, a giudizio mio, la prima edizione, alla quale poi nelle susseguenti si è cambiato il nome, & si sono accresciute le cose accennate in quella dell'anno.
# CELESTINA. Tragicommedia di Calisto, e Melibea tradotta dal Spagnuolo in Italiano (in prosa in atti ventuno). — Romae in Campo Flore per Magistrum Encarium Silter, alias Franck, anno 1506 die 29 Januari. in 4 — in Venezia, per Cesare Arrivabene Veneziano. 1519 adi 10 Decembre in 8 — ivi, per Gregorio de' Gregori nell'anno del Signore 1525 nel Mese di Novembre in 8 — ivi, per Gio. Antonio Nicolini. 1541 in 8 — ivi, per Bernardo de Bindoni, 1543 in 8 ed ivi, per il Giolito, 1553 in 8 — Prima di accennare in questo luogo il nome del Traduttore, siccome sono solito fare nelle traduzioni, mi conviene cercare quello dell'Autore, per togliere in questo modo di mezzo l'errore già preso da altri nel titolo dell'Opera, , e la confusione introdotta fra l'Autore, ed il Traduttore, l'Allacci, che certamente aveva avuta sotto l'occhio la Edizione dell'anno 1543 unicamente citata, la riferisce con questo titolo. Celestina, Tragicommedia di Calisto, e Melibea, ed a mio parere non si è ingannato, giacchè tutte le Edizioni da me vedute portano tutto quel titolo, e non già il solo di Calisto, e Melibea, siccome altri hanno fatto. Se però avesse osservato con più attenzione il Libro nel principio, e nel fine, ed avesse letti, come parmi doverebbe aver fatto, i Versi, che in un luogo, e nell'altro sono registrati, ed avesse voluto, con pochissima fatica, interpretarli, avrebbe trovato il nome dell'Autore indicato dal Traduttore, che parlando della Traduzione dice così: Nel mille e cinque cento cinque appunto De Spagnolo in Idioma Italiano È stato questo opuscolo transunto Da me Alfonso Hordognez (*) nato Hispano A instantia di colei, cha in se rasunto Ogni bel modo & ornamento humano Gentil Feltria Fregosa honesta e degna, In cui vera virtà triunfa e regna, (*) Hordognez, non Hordeze, come ha la Edizione dell'Arrivabene. Ma se è scusabile l'Allacci, che non ha voluto prendersi il fastidio di cercare l'Autore, non lo è però chi alla Tragicommedia, di cui qui si tratta, assegna per Autore Alfonso Ulloa, Personaggio assai noto (**), Se costui avesse badato agli otto versi, che precedono gli otto accennati, avrebbe saputo trovare il nome vero dell'Autore senza sbagliare, Eccogli: El debito non vuol nè la ragione Chel nome de l'Autor se scriva chiaro Però che esso ne è stato in suo sermone Un poco rispetto (forse rispertoso), un poco avaro. Ma pur per dar di lui cognitione In nelle prime stanze te limparo, Giù per li capi versi brevemente Con la sua dignità, natione, e gente. Ricorrendo pertanto nel principio della Tragicommedia di alcune Ottave, dal Traduttore chiamate stantie dello Authore, poste insieme le lettere iniziali, si avranno le seguenti parole. El Bacciler Fernando de Rojas fornì la Commedia de Calisto, e Melibea, e lui fu nato ne la Puebla de Montalbano. Il vero nome adunque dell'Autore della Tragicommedia, per cui si sono fatte tante parole, è Fernando de Roias del Villaggio di Montalbano, tradotta da Alfonso Ordognez. Il (**) Crescimb. Comment. &c. Vol. 1. lib. 4. p. 287. not. 82. Tragicommedia Spagnuola di atti ventuno intitolata di Calisto, e Melibea composta da Alfonso Ulloa, e stampata in Venezia dal Giolito nel 1553 la quale fu anche tradotta dal Castigliano nell'italiano, anch'esso Ingannato disse così.
# CEREALI. Commedia d'Aristofane tradotta dal Greco in lingua comune d'Italia (in prosa). — in Venezia, per Vincenzo Valgrisi, 1545 in 8. — di Bartolommeo, e Pietro Rosittini Fratelli, da Pratalboino.
# CERIMONIE. Commedia, — in Bologna, nella Stamperia di Lelio dalla Volpe, 1728 in 8 — in Venezia per Bonifacio Viezzeri. 1728 in 8 — ed in Verona, per Gio. Alberto Tumermani. 1730 in 8 con altre due Opere Drammatiche dello stesso Aurore, ed ivi, per Pier Antonio Berno. 1732 in 12 — quarta Edizione corretta &c. del Marchese Scipione Maffei, Veronese.
# CHI LA FA L'ASPETTA. "Questo il titolo di qualche Componimento Teatrale riferito nell'anno 1667 dal Libricciuolo de' Signori Soc. Filopatri di Bologna stampato in detta Città per Costantino Pisarri l'anno 1737 nel quale hanno preteso unire la serie cronologica de Drammi recitati su de Pubblici Teatri di Bologna dall'anno di nostra Salute 1600 sino al corrente 1737. In questo però, come pure in molti altri, si sono scordati di aggiungere al titolo verun altra particolarità.
# CID (il Gran). Dramma per Musica rappresentato nel Teatro di Livorno nel Carnevale dell'anno 1715 consacrato all'Alt. Reale della Sereniss. Violante Gran Principessa di Toscana. in Massa, per Pellegrino Frediani. 1715 in 8 — Poenia di Logildo Mereo, P. A. cioè, Gio. Giacomo Alborghetti, Bergamasco. — Musica di Giambatista Stuk.
# CIECO ERRORE. Commedia (in terzine). — in Venezia, per Gio. Antonio de' Niccolini da Sabbio. 1539 in 8 — Poesia di colui, che da' Rozzi è chiamato lo Stecchito, e dagli Uomini Antonio Maria da Siena.
# CLODOALDO PRINCIPE DI DANIMARCA. Tragedia data in luce. da Teodoro Pangalo insieme col Maurizio Imperadore. — in Roma, a spese di Giorgio Placco, 1711 in 8 del P. Gio. Lorenzo Lucchesini, della Compagnia di Gesù.
# COMMEDIA di Messer Lattanzio Vecchio, e della sua Innamorata Madonna Isabella. — in Venezia, per Matteo Pagan. 1555 in 8 — di Catullo, Cieco Muranese, detto Maretino.
# COMMEDIA d'un Cieco, e d'un Villano. — in Siena, senza Stampatore, ed anno. in 8 — del Falonio.
# COMPONIMENTO DRAMMATICO fatto per Musica nel giorno Natalizio della Sereniss. Maria Farnese Duchessa di Modona. — in Venezia, per li Giunti, e Baba, 1643 in 12 — colle altre Opere dell'Autore, — ed in Bologna, per Carlo Zenero, 1648 in 12 — colle altre Opere dell'Autore. — del Cav, Fulvio Testi, Modonese. 108.
# COMPONIMENTO per Musica (a tre voci) cantato a S. Alt. Reale, ed Elettorale Federigo Cristiano Figlio del Regnante Augusto di Polonia, ed Elettor di Sassonia, per comandamento di Sua Eccellenza il Sign. Don Giuseppe di Bacza, Evizentelo, Sumiglier de Cortina di S. M. Catt., Ab. de' Santi Pietro e Paolo d'Italia, e di Castro Xerrz, ed Ambasciadore Estraord. di S. M. il Re delle due Sicilie alla Sereniss. Repubblica di Venezia. — in Venezia. senza Stampatore. 1740 in 4 — Poesia, e Musica d'Incerti.
# CONGREGANTI. Commedia di Aristofane tradotta dal Greco in lingua comune d'Italia (in prosa): — in Venezia, per Vincenzo Valgrisi. 1545. in 8 — di Bartolommeo, e Pietro Rositini Fratelli, da Pratalboino.
# CONRADO. Tragedia Sacra. — in Palermo, per Pietro Coppola. 1641 in 8 del P. Ortensio Scamacca, Siciliano, Gesuita.
# CONTRAPOSTI AMOROSI, ovvero, i Rotti Incanti. Commedia Pastorale (in prosa). — in Modona, per Bartolommeo Soliani. 1648 in 12 — di Grisanto, Reggiano, Pittore.
# CONVERSIONE DI S. MARIA MADDALENA, ridotta in Tragedia — in Firenze, per li Giunti, 1609 in di Riccardo Riccardi, Fiorentino.
# CREONTE. Dramma per Musica. in Catania, per il Bisagni. 1686 in 12 — d'Ignazio Tedeschi, e Paterno, di Catania.
# CRISTO AL CENACOLO. Oratorio per Musica da cantarsi a San Tommaso Martire Congregazione de Preti di San Filippo Neri di Padova l'anno 1738 in Padova, per Giambatista Penada. 1738 in 8 — Poesia, e Musica d'Incerti.
# CRISTO SU L'ACQUE. Oratorio per Musica da cantarsi in San Tommaso Martire Congregazione de' Preti di S. Filippo Neri di Padova il Giovedi Grasso 1728 — in Padova, per Giambatista Conzatti. 1728 in 8 — Poesia, e Musica d'Incerti.
# DAVIDE, IL FORTE. Dialogo per Musica. — in Palermo, per Antonio Epiro, 1711 in 4 —di Giuseppe Caffora, di Palermo.
# DELFINO. Favola Pescatoria. — in Brescia, per Comino Prisegni. 1607 in 4 — de' Sig. Accademici di Salò.
# DESCRIZIONE DELLA MASCHERATA A CAVALLO, rappresentata il giorno Natalizio dell'Alt. Sereniss. di Rinaldo I. Duca di Modona, Reggio, &c. nel Cortile del Ducale Palazzo l'anno 1718 — in Modona, per Bartolommeo Soliani. 1718 in 8 — Poesia — di Diversi.
# DESIDERATO FINE. Commedia (in prosa). — in Mantova, per Venturino Ruffinello. 1544 in 8 — d'un Gentiluomo Mantovano.
# DIALOGO FRA UN SALIMBANCO ED UN CONTADINO (in terzetti). — in Siena, per Silvestro Marchetti. 1603 in 4 — del Falotico, della Congrega de' Rozzi, cioè, Giambatista, Sarto, Sanese.
# DIOMEDE. Dramma recitato l'anno 1716 nel Teatro Formagliari di Bologna — Poesia, e Musica di Francesco Antonio Novi, Napolitano.
# DISCORSI de' PASTORI intorno il Nascimento di Cristo. — in Roma, per li Facciotti. 1616 in 12 — ed in Viterbo, per Girolamo Discepolo. 1620 in 12 — Poesia, e Prosa di Francesco Magnoni, da Sant'Angiolo di Vado.
# DISPERAZIONI FORTUNATE, ovvero, li Finti Morti. Tragicommedia in Messina, per Vincenzo di Amico, 1688 in 12 — dì Natale d'Amico, Siciliano.
# DISPREGIO DEL MONDO. Oratorio per Musica cantato in S. Tommaso Martire di Padova de' Preti di S. Filippo Neri. — in Padova, per Giambatista Conzatti, 1727 in 8 — Poesia, e Musica d'Incerti.
# DONZELLO. Commedia, — in Venezia, per Bernardo Giunti. 1585 in 8, con altre del medesimo Autore, di Gio. Maria Cecchi, Fiorentino.
# DORI. Favola Pescatoria. — in Napoli, nella Stamperia di Gio. Domenico Montanaro. 1634 in 12 — d'Isabetta Coreglia, Lucchese.
# DUCA DI GUISA. Tragedia (in versi sciolti) — in Milano, nella Stamperia di Giuseppe Pandolfo Malatesta. 1728 e 1730 in 8 — ed in Venezia, per Gio. Batista Albrizzi. 1732 in 12, con le altre dell'Autore. del Marchese Giuseppe Gorini Corio, Milanese.
# DUE FRATELLI, ovvero, li Menecmi di Terenzio tradotto da Niccolò Fortiguerra di Pistoja, Canonico di S. Pietro di Roma. — in Urbino, per il Mainardi. 1736 in foglio fig. con le altre di Terenzio tradotte dal detto, — in Milano, nella Stamperia Ducale 17. in 4 nel Tom. de' Poeti tradotte coll'altre. — in Venezia, per Simon Occhi, 1748 in 8 coll'altre di Terenzio tradotte dal detto.
# DUELLO D'AMORE E DI FORTUNA. Commedia (in prosa). — in Ronciglione, per il Colaldi, e Domenico Domenici. 1609 in 12 — degli Accademici Desiderosi, di Ronciglione.
# EAUTONTIMORUMENO. Commedia di Terenzio fatta tradurre in lingua volgare da Giambatista da Borgo Franco (in prosa) con tutte l'altre dello stesso Terenzios — in Venezia, per Giovanni Padovano l. 1544 niin 8 — d'Incerto Traduttore.
# EAUTONTIMORUMENO. Commedia di Terenzio di nuovo corretta ed a miglior traduzione ridottà.(in prosa con tutte l'altre) — in Venezia, nelle Case de Figliuoli di Aldo. 1546 in 8 — d'Incerto Traduttore.
# ECIRAE. Commedia di Terenzio fatta tradurre, in Lingua Volgare da Giambatista da Borgo Franco (in prosa con tutte l'altre di Terenzio). in Venezia, per Govann Pabovana in 8 — d'Incerto Traduttore.
# ECIRA. Commedia di Terenzio di nuovo corretta, ed a miglior traduzione, ridotta (in prosa con tutte le altre di Terenzio): — in Venezia, nelle Case de' Figliuoli di Aldo, 1546 in 8 — d'Incerto Traduttore.
# EGLOCA PASTORALE nel modo, che fu rappresentata nella Città di Vinegia, (in cinque Atti, tutti in versi sdruccioli) dedicata al Magnifico Sig. Marco Caotorta del Clarissimo Mess. Giambatista. — in Vinegia senza Stampatore. 1558 in 8 Giambatista Uberti.
# ELIANTO PRINCIPE DI CIPRO. Tragicommedia tradotta nella Lingua Italiana (in prosa) con gl'Intermedi. — in Bracciano, per Andrea 1633 in 12 — L'Autore è Cinto Aldimacchio di Friama, Accademico Eteroclito, ed il Tradutiore è Acadio Berlinzi, di Città di Castello.
# ELPINO. Componimento Pastorale cantato nell'Accademia de' Signori Animosi di Venezia nel Palazzo di S.E. il Sig. Gio. Carlo Grimani il di primo Febrajo dell'anno 1701 — degli Accademici Animosi.
# EMPIETÀ DELUSA. Oratorio cantato nell'Augustissima Cappella della Sacra Ces. Catt. R. M. di Carlo VI Imperadore de' Romani sempre Augusto l'anno 1715 — in Vienna, per gli Eredi Cosmeroviani 1715 in 4 — Poesia, di Carlo Giuseppe Cornacchia, di Casal Monferrato, Accademico Affidato. — Musica di D. Gio. Antonio Costa.
# ENIGMA DEL FATO SCIOLTO GIOVE. Scherzo Musicale recitate nel Giorno del gloriosissimo Nome della S. C. R. M. di Giuseppe I. Re de' Romani l'anno 1707 — in Vienna, per Pietro Van Ghelenin 8 — E nella P.1 le Poesie Dramma Autore di Pier'Antonio Bernardone Bolognese.
# EPISTOLE E DIALOGHI, E CAPITOLI. Tragedia (in terzine) — in Venezia, per Marchio Sessa, 1506 in di M. N.D.
# ERCOLE. Dramma per Musica (in tre sole Scene). — in Roma, per Fabbrizio di Falco. 1670 in 8, coll'altre Poesie Drammatiche dell'Autore.di Lodovico Casale, Romano.
# ERCOLE IN CIELO. Festa Musicale nel giorno del Gloriosissimo Natale della S. C. R. C. M. dell'Imperadore Carlo VI. per comando della Sac. Ces. R. Catt. M. dell'Impera296 ER drice Elisabetta Cristina nel suo Ces. Palazzo l'anno 1713 — in Vienna, per gli Eredi Cosmeroviani. 1713 in 4 — Poesia, e Musica d'Incerti Autori.
# ERCOLE IMPAZZITO. Dramma recitato nel Palazzo Porta al Giardino in Bologna l'anno 1628 — del Tenebroso.
# ERGILDA. Dramma rappresentato nell'anno 1736 in Venezia nel Teatro di Sant'Angiolo. — in Venezia, per Marino Rossetti. 1736 in 12 — poesia di Bartolommeo Vitturi, Veneziano. — Musica di Baldassarre Galuppi, Veneziano.
# ERGINIA MASCHERATA. Dramma recitato nel Teatro Campagnella di Rovigo l'anno 1727 — in Venezia. senza nome di Stampatore. 1727 in 12 — E una replica del sopraddetto. Musica, per la maggior parte, del Canonico Angelo Cappello.
# ERMIONA. Introduzione d'un Torneo a piedi, e a cavallo, e d'un Balletto rappresentato in Musica nella Città di Padova l'anno 1636 — in Padova, per Paolo Frambotto. 1631 in 4 — Poesia, e Prosa del March. Pio Enea Obizzi.
# ERRORE INNOCENTE, ovvero, gli Equivoci nel Sembiante. Dramma recitato l'anno 1679 nel Teatro Formagliari di Bologna. — Poesia, e Musica d'Incerti Autori.
# ESTER TRIONFANTE. Dramma recitato l'anno 1700 in Sicilia, di Francesco Avola, Siciliano.
# EUNUCO. Commedia di Terenzio intitolata l'Eunuco dal latino al volgare tradotta, con somma diligenza revista, corretta, e nuovamente stampata del 1532 — in Venezia, per Niccolò d'Aristotile detto Zoppino del Mese di Luglio 1532 in 8 — d'Incerto Traduttore.
# EUNUCO. Commedia di Terenzio fatta tradurre in lingua volgare da Gio. Batista di Borgo Franco (in prosa) — in Venezia, per Giacob da Borgo Franco, Pavese, del Mese di Marzo 1538 in 8, colle altre cinque di Terenzio. — ivi, per Gio. Padovano. 1544 in 8 — d'Incerto Traduttore.
# FANTESCA. Commedia (in prosa in cinque Atti). — in Venezia, per Gio. Batista Bonfadino. 1592 1596 e 1610 in 12 — ivi, per Gio. Batista, e Gio. Bernardo Sessa, 1597 in 12 — ed in Napoli, nella Stamperia, ed a spese di Gennaro Muzio. 1726 in 12 — nel Tom. III. delle Opere dell'Autore.  di Giambatista—della Porta, Napoletano.
# FEDE CREDUTA TRADIMENTO. Dramma recitato a Roncade (Villaggio del Territorie Trevigiano) l'anno 1692, e poi nel Teatro di S. Mosè di Venezia l'anno 1693 — in Venezia per il Niccolini, 1692 in 12 — sia di D. Marc'Antonio Gasparini Veneziano, Sacerdote, della Chiesa di San Martino, e poi Piovano della medesima. — Musica di Giovanni Frezza, Trivigiano.
# FEDE INNALZATA SOPRA LE CADUTE DELL'INGANNO NELLA PREDICAZIONE, E MARTIRIO DEL GLORIOSO APOSTOLO ED EVANGELISTA SAN MATTEO. Morale Rappresentazione (in prosa) recitata dal Genio devoto di diversi Giovani Veronesi, — in Verona, per li Fratelli Merli. 1696 in 12 — col Prologo, due Intermedj, ed'un Concilio tenuto nell'Inferno da Demonj, in versi — Poesia, e Prosa di C. A. B.
# FELICITA REGNANTE. Serenata al Sereniss. Principe di Venezia Luigi Contarini, cantata l'anno 1681 in Canonica di San Marco di Venezia nella di lui Assunzione al Principato. del Canonico Cristoforo Ivanovich Dalmatino. — Si trova stampata a parte, e poi inserita nella Parte seconda della Minerva al Tavolino dello stesso Autore, appresso Niccolò Pezzana 1687. in 12 — c. 103. In essa Parte II. si legge anche una lettera allo stesso Principe c. 101, e la descrizione della Serenata a c. 113. e seg.
# FENICIANE. Tragedia di Euripide (in prosa). Manca il Luogo, lo Stampatore, e l'anno, in 8 — Ed anche il nome del Traduttore.
# FIGLIO PRODIGO. Dramma per Musica. — in Genova, nella Stamperia di Benedetto Guasco. in 8 — Allacci lo crede opera di Anton Giulio Brignole Sale, Genovese.
# FILENA. Egloga chiamata Filena (in terza rima) — in Venezia, per Gabriele Giolito de Ferrari. 1546 in 8 insieme colle altre Poesie dell'Autore.di Gio. Agostino Cazza, Novarese, detto Lacrito nell'Accademia de' Pastori.
# FINZIONE. Prologo con Rime di quattro Intermedi apparenti cantati nella Filli di Sciro Pastorale di Guidubaldo Bonarelli recitata in Macerata l'anno 1619 — in Macerata, per Pietro Salvioni. 1619 in 12 — d'Ippolito Aurispa.
# FORMIONE. Commedia di Terenzio fatta tradurre in Lingua Volgare da Giambatista da Borgo Franco (in prosa) colle altre di Terenzio. — in Venezia, per Jacob da Borgo Franco Pavese del mese di Marzo 1538 in 8, colle altre cinque di Terenzio, in Venezia, per Giovanni Padovano. 1544 in 8 — d'Incerto Traduttore.
# FURBERIE DI SCAPPINO. Commedia del Molier tradotta (in prosa). — in Lipsia, per il Gleditsch. 1698 in 8 Nel Tom. II. delle Opere del Molier, da Niccolò de' Castelli.
# GARE DEL MERITO. Tragicommedia (in prosa) — recitata in Modona il Carnevale dell'anno 1664 — in Modona, per Bartolommeo Soliani. 1664 in 12 — e in Brescia, per li Rizzardi. 1675 in 12, colla giunta del Prologo, e degl'Intermedj, di Gio. Batista Boccabadati.
# GELOSIA NEL CAVALLO (la), ovvero Inganno per Inganno. Opera Regia (in prosa) — in Bologna. 1694 in 12 — D. Domenico Veraldo.
# GENEROSITÀ POLITICA. Dramma rappresentato nel Teatro di S. Samuele di Venezia per la Fiera dell'Ascensione dell'anno 1736 — in Venezia, per Marino Rossetti. 1736 in 12 — Poesia del Lalli, e del Goldoni. — Musica di Giammaria Marchi, Milanese. Santa.
# GERMANICO SUL RENO. Dramma per Musica. — in Milano, per gli Eredi di Filippo Ghisolfi, 1677 in 12 — di Ascanio, Lonati.
# GEZABELLE. Tragedia. — in Venezia, per l'Albrizzi. 1732 in 8 nel Tom. I. del Teatro, Tragico e Comico dell'Autore. — in Milano, per l'Agnelli 1744. in 12 — nel Tom. III. del Teatro Tragico dell'Autore. March. Gioseffo Gorini Corio, Milanese.
# GINETTA. Egloga Pastorale intitolata la Ginetta. — in Siena, per M. di F. B. ad istanza di Maestro Giovanni di Alessandro Librajo, adi 27 di Ottobre 1524 in 4 — composta per lo ingegnosissimo Uomo Maestro Niccolò Alticozio, Cortonese.
# GIUDITTA TRIONFANTE. Rappresentazione. — in Napoli, per il Cavallo, e il Marzi. 1685 in 12 — Giulio Cesare Sorrentino.
# GIUDIZIO DI PARIDE SUL MONTE IDA. Intermezzo per Musica cantato nell'Accademia de Signori Animosi di Venezia a' 31 Gennajo l'anno 1699 nel Palazzo di S. E. il Sig. Gio. Carlo Grimani, Patrizio Veneto. — in Venezia, senza Stampatore. 1699 in 4 — Poesia de' Signori Accademici Animosi. — Musica di Carlo Francesco Pollaroli, Bresciano.
# GIUDIZIO DI PARIS. Egloga Pastorale, colla forza in ogni terzetto de Versi del Petrarca, dell'Ariosto, e del Sannazaro, con alcune Sentenze di Dante, e d'altri, in Napoli, per Gio. Batista Sottile. 1602 in 4 — tradotta in versi da Donato Porfido Bruno, di Venosa.
# GIUSTINO. Tragedia. in Venezia, per il Bettinelli. 1733 in 4 e in 12 — Nel Tom. III. dell'Opere dell'Mutore. — detl. Ab. Pietro Metastalio, Romano.
# GLORIOSO (Il). Commedia di M. Nericault Destouches tradotta (in prosa). — in Venezia, per Modesto d'Incerto, Fenzo 1743 in 8
# GRAZIANA. Favola Boschereccia (in versi sciolti) — in Padova, per Gio. Cantoni. 1588 in 8 — in Venezia, per Giovanni Alberti. 1599 in 8 ivi, per Giorgio Rizzardo. 1609 in 12 — ed ivi, per Lucio Spineda. 1621 in 12 — dell'Infiammato.
# GRISANTO, E DARIA. Oratorio per Musica recitato a S. Tommaso Martire de Preti di S. Filippo Neri di Padova, — in Padova, per Giambatista Penada, 1739 in 8 — Poesia, e Musica d'Incerti.
# IFIDE, ovvero, l'Amore non può celarsi. Commedia (in prosa), — in Viterbo. senza Stampatore. 1717 in 12 — D. Domenico Coccia.
# INCANTO. Componimento per Musica rappresentato nel giorno 15 di Giugno dell'anno 1604 alla presenza del Sereniss. Principe di Venezia Marino Grimani. — in Venezia, senza Stampatore. 1604 in 4 — d'Incerta Autore.
# INGANNATI. Commedia (in prosa) celebrata ne' Giuochi del Carnevale in Siena l'anno 1531 sotto il Sodo dignissimo Archintronato (Mare Antonio Piccolomini). — in Venezia, per Curzio Navò, e Fratelli, 1538 in 8 — ivi, per Agostino Bindoni. 1550 e 1554 in 8 — ivi, per Plinio Pietrasanta. 1554 in 8, colle Annotazioni di Girolamo Ruscelli, o con altre quattro Commedie. — ivi, per Gabriele Giolito de' Ferrari. 1559 in 12 — ivi, per Francesco Rampazzetto. 1562 e 1567 in 12 — ivi, per Domenico Farri, 1563 in 8 — ivi, per Altobello Salicato. 1569 in 12 — ivi, per Filippo, e Bernardo Giunti. 1597 in 12 — ivi, per Domenico Cavalcalupo. in Ferrara, ad istanza di in 8 Alfonso Caraffa. 1587 in 8 — in Venezia, per Michele Bonibelli. 1595 in 12 — ivi, per Antonio Turriani. 1609 in 12 — ed in Siena, per Matteo Florini. 1611 in 12 — degli Accademici Intronati di Siena. — In questo luogo credo non essere fuor di proposito il correggere l'errore preso dall'Allacci, e spiegare la ragione, che l'ha indotto ad errare. Suole questa Commedia portare il titolo di Commedia del Sacrifizio degl'Intronati, onde a prima vista parrebbe, che con quello devesse nel Catalogo registrarsi. Ma quello, cui non basta la lettura de titoli, e de frontespizj, ed ha l'accortezza di vedere, ed esaminare con occhio curioso le Edizioni, senza fidarsi delle relazioni degli altri, non così di leggieri è soggetto a certi sbagli, che sono importanti, benchè non pajano. Da ciò, che segue dopo il titolo mentovato pertanto si comprende, che un Ministro, cui si dà il nome di Sacerdote fa in versi un Prego agli Dei, ed esorta gli Accademici Introuati assistenti ad offerire un Sacrifizio a Minerva con queste parole. Ciascun ciò, che tenea della sua Donna Per furto, o dono, o qualsivoglia caso ha qui portato, e sopra questo Altare al Sacro fuoco lo vuol dare in preda, ed a tuoi studi poi volger la mente, Per alzarsi da terra, e farsi eterni. Su dunque, devotissimi Intronati, Ponete in opra il santo, e bel desio, Scogliete Voi Ministri tutti i nodi, Ed io con tre color cingo l'Altare In effetto al Prego succedono le offerte di trenta Accademici Intronati co loINro Nomi Accademici, ciascheduno, de quali gitta nel fuoco la cosa più cara, che teneva dalla sua Donna, recitando, chi un Sonetto, chi un Madrigale, o qualche altra breve Canzona. Finita la Cerimonia, e cantate da quello, che prima venne colla Lira, sei Stanze, si legge. il fine del Sacrifizio. A questo siegue subito il Prologo degl'Ingannati, e dappoi la Commedia in cinque Atti, nel fine de quali, e dopo la Licenza, si legge pure. Finiscono gl'Ingannati degl'Intronati.
# INGANNI INNOCENTI, ovvero, Adalinda. Favola Drammatica Musicale. — in Ronciglione. senza Stampatore. 1673 in 12 — degli Accademici Sfaccendati. — Replicata gli anni 1675 e 1695 nella Città di Bologna.
# INNOCENZA D'AMORE. Dramma rappresentato l'anno 1661 nelle Ville di Persiceto del Bolognese. — del Caliginoso, cioè, Melchior Zoppio, Bolognese.
# INNOCENZA PERSEOUITATA, ovvero, Santa Trosimena. Tragicommedia Sacra, — in Napoli, nella Stampa di Michiel Luigi Muzio 1720 in 12 — Poesia data in luce da Carmine Scaffafer.
# IPPOLITO. Tragedia tratta da quella di L. Anneo Seneca (in cinque Atti, ed in versi sciolti) — in Torino, per Bartolommeo Zapatta. 1661 in 8 del Co. Emanuello Tesauro.
# IPPOLITO. Tragedia di Seneca tradotta (in verso). — in Venezia per il Geremia. 1730 in 8, con altre quattro tradotte dallo stesso da Benedetto Pasqualigo, Pattrizio Veneto.
# IPPOLITO REDIVIVO. Dramma raccorciato già e abbassato per la Musica dalla Tragedia dello stesso titolo, di Liopardo suddetto. — in Venezia, per Francesco Valvasense, 1659 in 12 — Dalla Lettera Dedicatoria del Bontempo scritta alle Catt. Maestà del Re, e Regina di Spagna in data il di primo Ottobre 1659 si vede, che tale raccorciamento fu opera sua. Seguono gl'Intramezzi, pure in Versi, dedicati alle stesse Regie Maestà col titolo di Amor Conjugale.
# LETTERE DI CAMBIO. Commedia (in prosa) rappresentata in Siena. in Viterbo, per Girolamo Discepolo. 1606 in 12 — ed in Venezia, per Gio. Alberti. 1606 in 12 — degli Accademici Sviati di Siena. — Da Francesco Claudi è dedicata allo Illustriss. ed Eccellentissimo Signor D. Mario Farnese, in data de 2 Febbrajo 1606.
# LIBERAZIONE DE' SANTI PADRI DAL LIMBO. Rappresentazione. — in Verona, nella Stamperia di Giambatista Gelmini. 1610 in 4 — del Filotheoro, Accademico Olimpico di Vicenza, Spensierato di Ferrara, ed Unito di Cortona.
# LISISTRATA. Commedia di Aristofane tradotta dal Greco in lingua comune d'Italia. — in Venezia, per Vincenzo Valgrisi. 1545 in 8, insieme colle altre dello stesso, tradotte dai medesimi Traduttori. — di Bartolommeo, e Pietro Fratelli Rositini, da Pratalboino.
# MADDALENA LASCIVA, E PENITENTE. Azione Drammatica, e divota rappresentata in Milano, e dedicata all'Illustrifs. Sig. Co. Paolo Bolognini, in Firenze, per gli Eredi di Cristofano Marescotti. 1612 in 4in Milano per Giambatista, e Giulio Cesare Malatesta, senz'anno, in 8 — La Dedicatoria à in data di Milano il 17 Agosto 1652 di Giambatista Andreini, Fiorentino, Comico, detto Lelio Fedele. — La medesima intitolata. la Maddalena, Composizione Sacra. — Pragæe prope excudebat Sigismundus Leva. 1628 in 12
# MANLIO CAPITOLINO. Tragedia tradotta dal Francese di M. de la Fosse (in prosa). — in Bologna, nella Stamperia di Lelio della Volpe. 1724 in 12, con molte altre. — d'Incerto Traduttore.
# MAOMETTO. Tragedia di M. Voltaire, tradotta (in prosa) — in Modona, senza Stampatore, 1747. in 12. del March. Fontanella.
# MARIA MADDALENA. Oratorio recitato in Musica il giorno (della Festività di detta Santa), dedicato al Sereniss. Marc'Antonio Zustinian da Fratelli dell'Oratorio degl'Incurabili di Venezia, — in Venezia, per Girolamo Albrizzi. 1686 in 12 — Poesia, e Musica d'Incerti.
# MARIA STUARDA. Tragedia, tradotta dal Francese, e rappresentata da Signori Convittori del Collegio de Nobili di Sant'Antonio di Brescia diretto da' PP. della Compagnia di Gesù nel Carnevale dell'anno 1716 — in Brescia, per Giammaria Rizzardi. 1716 in 12 — d'Incerto Traduttore.
# MARIA STUARDA. Tragedia tradotta dal Francese di M. Borseault (in prosa) — in Bologna, per Lelio della Volpe. 1724 in 12, con molte altre. — d'Incerto Traduttore.
# MARTIRIO DI SANT'AGNESE. Opera Scenica (in prosa) — in Parma, per il Vigna. 1659 in 8 del P. F. Carlo Tinti, Parmigiano, Minore Conventuale.
# MASSIMIANO. Tragedia tradotta dal Francese di M. Corneille (in prosa). — in Venezia, per Domenico Lovisa, senz'anno, in 12 — d'Incerto Traduttore.
# MASSIMIGLIANO. Opera rappresentata (un prosa) nel Ducale Collegio de' Nobili di Parma nel Carnevale dell'anno 1696 — in Parma, pergli Eredi di Galeazzo Rosati. 1696 in 4 del P. Paolo Pedrusi, della Compagnia di Gesù.
# MEDICO A SUO MALGRADO. Commedia di M. Molier. tradotta (in prosa). — in Lipsia, per il Gleditsch 1698 in 12 — colle altre Commedie del Molier. da Niccola de' Castelli.
# MELICERTA. Commedia di M. Molier tradotta (in prosa). — in Lipsia, per il Gleditsch. 1698 in 12 — coll'altre Commedie del Molier T.IV. da Niccola de' Castelli.
# MERAVIGLIE DEL SANT'ANGELO CUSTODE, ovvero, lo Schiavo del Demonio. Rappresentazione. — in Napoli, per il Savio, e Novello de Bonis. 1672. in 12 — d'Onofrio Giliberto.
# MIRTILLA. Favola Pastorale dedicata all'Illustriss. ed Eccellentissima Signora Donna Lavinia della Rovere Marchesa del Vasto (in prosa) — in Verona, per Sebastiano dalle Donne, e Camillo Franceschini Compagni. 1588 in 8 — in Ferrara, per Vittorio Baldini. 1590 in 8 — in Venezia, per Marc'Antonio Bonibello. 1590 in 8 — in Verona, per Francesco dalle Donne, e Scipione Varignano. 1599 in 8 — in Venezia, per Lucio Spineda, 1602 in 8 in Milano, per Girolamo Bordoni, e Pier Maria Loccarini. 1605 in 12 — ed in Venezia, per l'Imberti, 1616 in 12 — d'Isabella Andreini, Padovana, Comica Gelosa, ed Accademica Intenta.
# MIRTILLO. Favola Pastorale. — in Bologna, per il Ferroni, 1650 in 12 — del Traffillicense.
# MORTE DI NERONE. Tragicommedia (in versi di tredici sillabe in cinque Atti). — in Roma, per Francesco Gonzaga. 1715 in 8, colle altre Poesie Drammatiche dell'Autore, di Pier Jacopo Martello, Bolognese.
# MORTE DI DIDONE. Tragedia. — in Venezia, per il Fenzo. 1748 in 8 del Co. Landini, Bolognese.
# MOSÈ BAMBINO ESPOSTO AL NILO. Oratorio recitato a San Tommaso Martire di Padova, per il Conzat 1728 in 12 — Poesia, e Musica d'Incerti.
# MUZIO SCEVOLA. Dramma recitato nel giorno del felicissimo Nome della S. C. R. M. dell'Imperadrice Amalia Willelmina, per comando della S. C. R. M. di Giuseppe I. Imperadore de' Romani sempre Augusto l'anno 1710 — in Vienna, per gli Eredi Cosmeroviani. 1710 in 8 — Musica di Giovanni Bononcini, Bolognese. E una replica del suddetto con qualche variazione.
# NARSETE. Tragedia. — in Milano, per l'Agnelli. 1745 in 12 — nel T.V. del Teatro Tragico del detto. del Marchese Gioseffo Gorini Corio, Milanese.
# NEBULE DI ARISTOFANE. Commedia tradotta (in prosa) nella Lingua comune d'Italia. — in Venezia, per Vincenzo Valgrisi. 1545 in 8 — di Bartolommeo, e Pietro Rositini, da Pratalboino.
# NINFA CARCERATA. Favola Boschereccia. — in Mantova, per Aurelio, e Lodovico Osanna Fratelli. 1618 in 4 — dell'Infuocato.
# NINFA GELOSA. Favola Pastorale. in Venezia, per Roberto Mejetti. 1604 in 12 — ed ivi, per Evangelista Deuchino. 1620 in 12 — purgata, e revista dall'Autore, di Carlo Fiamma, Veneziano.
# NINFA RITROSA. Favola Pastorale. in Ancona, nella Stamperia di Ottavio Beltramo, 1651 in 4 colle altre Opere dell'Autore, del Co. Pietro Bonarelli della Rovere d'Ancona.
# NINFE (O NIMPHE) DI AMETO. Commedia delle Nimphe Fiorentine (in prosa, ed in terza rima). — in Venezia, senza Stampatore, sedente nella Cattedra di Pietro Sisto IV. Pont. Mass. l'anno VII. del suo Pontificato. 1478 in 4 — e ivi, per Gabriele Giolito de Ferrari. 1545 in 8 colla dichiarazione de' luoghi difficili di Messer Francesco Sansovino, scritta alla Nobiliss. Madonna Gaspara Stampa. — Poesia, e Prosa di Giovanni Boccaccio, da Certaldo.
# NIOBE. Tragedia. — in Venezia, per gli Eredi di Posca Librajo. 1595 in 8 del Pad. Gio. Angiolo Lottini, Servita.
# NOZZE DI PSICHE, E CUPIDINE. Componimente (in verso) celebrate pel Marchese Galeotto dal Carretto. senz'Autore, luogo, e Stampatore. in 8.
# OLDAURA. Tragedia dedicata dal Autore al Serenissimo Sig. D. Ferdinando Gran Duca di Toscana, &c. &c. in Venezia, per Giorgio Valentini. 1620 in 12 — ed in Trevigi, per Aurelio Righettini. 1630 in 12. dedicata dallo stesso Autore al Serenissimo Signor D. Francesco Gonzaga di Giulio Principe di Mantova Malmignati, Gentiluomo di Lendinara, che dice d'averla composta non per anche arrivato all'età degli anni diciotto.
# OLMIRO. Regi—Pastorale dedicata all'Alt. Serenissima di Vittoria, Principessa di Urbino, Gran Duchessa di Toscana. — in Roma, per Ivon Cavalli. 1655 in 12 — ed ivi, per gli Eredi del Corbelletti, 1657 in 12 del Co. Pietro Bonarelli della Rovere, di Ancona.
# OMBRE SVELATE. Oratorio — in Milano, nella Stamperia di Lodovico Bianchi. 1717 in 4 diF.T.A.R. cioè, Fr. Tommaso Agostino Ricchini, Cremonest T'
# ONESTÀ PROTETTA DAL CIELO. Dramma recitato l'anno 1600 in Bologna in Casa Bentivoglio. — del Compassionevole.
# ORATORIO DI SAN FILIPPO NERI (a sei voci, e in tre parti). — in Bergamo, per li Fratelli Rossi. 1698 in 4 — Poesia, e Musica d'Incerti.
# ...
# UCCELLI. Commedia di Aristofane tradotta dal Greco nella Lingua comune d'Italia. — in Venezia, per Vincenzo Valgrisi. 1545 in 8 — da Bartolommeo, & Pietro Rositini, da Pratalboino.
# VEREMONDA L'AMAZZONE D'ARAGONA. Dramma ridotto in nuova forma da Luigi Zorzisto, posto in Musica da Francesco Cavalli, e adornato con apparenza di Scene, Macchine, e Balli da Giambatista Balbi, Napoli, per Roberto Mollo, 1652 in 12.
# VERNO PASTORALE (Il). — in Milano, per Pandolfo Malatesta. 1623 in 12 — Poesia del Selvaggio, Accademico Pacifico.
# VESPE (Le). Commedia di Aristofane tradotta dal Greco in Lingua comune d'Italia.in Venezia, per Vicenzo Valgrisi. 1545 in 8 — di Bartolommeo, e Pietro Rositini, di Prat'Alboino.
# VISITA DELLI PASTORI AL BAMBIN GESÙ'. Oratorio in Musica recitato nell'Oratorio de' Preti di San Filippo Neri di Padova nelle Feste del Santissimo—Natale. — in Padova, per il Penada, 1728 in 8— Poesia, e Musica d'Incerti.
# ZANIN DA BOLOGNA. Commedia (col nome di Frottola). — Il Crescimbeni, che la riferisce (Coment. Vol. I lib. 4. p. m. 261. della Edizione di Venezia) dice solamente, che impressa senza l'anno della Edizione.
# ZOCCOLETTA PIETOSA. Commedia (in prosa). — in Venezia, per Simone Occhi, 1743 in 8 — L'Autore si nascose sotto questo vivacissimo nome: Di chi la scrisse. — ma è il Sig. Ab. Vincenzo Rota, Padovano.
# ACHILLE IN SCIRO. Dramma, in Venezia, per il Bettinelli. 1737 in 4 Nel Tom. IV. delle Opere Drammatiche dell'Autore divise in Tomi V. ed in altre Edizioni susseguenti dello stesso. — . dell'Ab. Pietro Metastasio, Romano.
# ALZIRA. Tragedia di M. Voltaire tradotta (in prosa). — in Firenze, nella Stamperia Imperiale. 1752 in 12 — con altre 7. Tragedie dell'Autore in Tomi due, nel Tom. II. di A. M.
# AMANTE FEDELE, PANTALONE OMICIDA ED IL DOTTORE DISONORATO ONORATAMENTE. Commedia (in prosa). — in Venezia, per il Lovisa, senz'anno. in 12 — del Capriccioso.
# ALFIER FANFARONE. Intermezzi. senza luogo, Stampatore, ed anno in 12
# AMARE, E FINGERE. Commedia (in 16 —prosa). — trasportata dallo Spagnuolo. — in Venezia, per il Zini 1675 data in luce da Domenico Antonio Parrino, detto Florindo Comico.
# ANDROMACA. Tragedia di Euripide tradotta (in versi) dal P. Carmeli Min. Osserv. — in Padova, per il Manfrè. 1747 in 8, col Testo Greco a riscontro, e con tutte l'altre d Euripide.
# ARLECHINO SALVATICO. Commedia tradotta dal Francese. — in Firenze, per il Bonducci, 1754 in 8 — di M.
# ARMIDA AL CAMPO. Dramma in Venezia, per il Voltolini. 1744 in 12 — nel Tom. I. delle Opere Drammatiche dell'Autore divise in IV. Tomi. — . dell'Ab. Francesco Silvani, Venez.
# ARZIGOGOLO. Commedia (in prosa). in Firenze, (ma è Venezia) 1750 in 8 nella Raccolta di varie antiche Commedie in sei Tomi intitolata Teatro Comico Fiorentino nel Tom. IV.
# ATTALIA. Tragedia del Racine tradotta da D. Bonifazio Collina Ch. Reg. Som. — in Venezia, per il Valvasense. 1751 in 8 — nel Teatro Ebraico in III. Tomi, Tom. I.
# ATTILIO RECOLO. Dramma — in Venezia, per il Pasinelli. 1750 in 12 — ivi, per il Bettinelli. 1752 in 12 — nel Tom. IV. delle Opere Drammatiche dell'Autore divise in VI. Tomi. — . dell'Ab. Pietro Metastasio, Romano, Poeta Cesareo.
# BATTAGLIA SPIRITUALE. Oratorio. in 8.
# CALUNNIA CONVINTA nella Conversione de' SS. Eugenia, Proto, e Giacinto. Melodramma. — in Roma, per il Buagni, 1 1706 in 12, cogli altri Melodrammi dell'Autore. — in di Arcangelo Spagna.
# CARNE DOMATA. Santa Maria Egiziaca, in 12 — del Franchi.
# CATILINA. Tragedia di M. di Crebillon il Giovane (in versi) — in Venezia all'Insegna della Scienza. 1751 in 12 — Tradotta dall'Abate Pietro Chiari, Bresciano.
# CICLOPE. Tragedia di Euripide tradotta (in versi). — in Padova, per il Manfrè.1751 in 8 — Tragedia XIV colle altre dell'Autore. del P. Michelangiolo Carmeli.
# CLEMENZA DI TITO. Dramma. — in Venezia, per il Bettinelli. 1737 in 4 — nel Tomo IV. dell'Opere dell'Autore. — ivi, per lo stesso. 1751 in 12 — nel Tomo II. ed in altre molte Edizioni. — . dell'Ab. Pietro Metastasio, Romano.
# COMICO DEL CIELO nella Conversione di S. Gennesio. — in Roma, per il Buagni. 1706 in 12 — cogli altri Melodrammi dell'Autore. — d'Arcangelo Spagna.
# CLITANDRO. Tragedia di Pietro Cornelio tradotta (in prosa). — in Venezia, per il Lovisa. 1747 in 12 — d'Incerto Traduttore.
# CONTESA DE' NUMI. Festa Teatrale. in Venezia, per il Bettinelli. 1733 in 4 — nel Tom. II. delle Opere dell'Autore. — ivi, per lo stesso, 1752 in 12 — nel Tomo V. ed in altre molte Edizioni dello stesso, del Dottor Carlo Goldoni, Veneziano.
# CONVITATO DI PIETRA. Commedia di M. Molier tradotta (in prosa). in Lipsia, per il Gleditsch. 1698 in 12 — nel Tomo II. delle Opere del Molier, da Niccola de Castelli.
# CORDOVA TRIONFANTE NELLA COSTANZA de' SS. Martiri Vittoria, ed Acisclo. Melodramma. — in Roma, per il Buagni, 1706 in 12 — cogli altri Melodrammi dell'Autore. — d'Arcangelo Spagna.
# COSTANTINO. Tragedia. — in Verona, per il Ramanzini. 1752 in 8 del P.Bonavventura Antonio Bravi. Questa è una Tragedia composta dalle due dello stesso Autore Irene delusa, e Costantino Depresso.
# DEMETRIO. Dramma. — in Venezia, per il Bettinelli, 1733 in 4 nel Tomo I. delle Opere dell'Autore divise in V. Tomr. — ed ivi, per il detto. 1750 in 12 — nel Tomo I. delle Opere Drammatiche dello stesso divise in VI. Tomi, ed in varie altre Edizioni dell'Ab. Pietro Metastasio, Romano.
# DON PASQUALE IN VILLA. Commedia (in prosa). — in Ronciglione, per il Leone. 1675 in 12 — del Roncini.
# DORI, ovvero, la Schiava Fedele. Dramma in 12.
# EDIPO. Tragedia di Pietro Cornelio tradotta (in versi), — in Venezia, per il Bertella. 1748 in 4 nel Tomo III. delle Tragedie di Cornelio. da Giuseppe Baretti, Torinese.
# ELENA CASTA. Tragedia. — in Bologna, per Lelio dalla Volpe, 1733 in 8 nel Tomo IV. delle Opere dell'Autore.
# ENEA IN CARTAGINE. Tragedia (in versi). — in Venezia, per Modesto Fenzo. 1748 in 8 — del Gandini, Bolognese.
# ERROR DE' BIGLIETTI. Azione Drammatica. — in Milano, in 12 — del Franceschini.
# EVERGETE. Dramma da rappresentarsi in Venezia nel Teatro di S. Gio. Grisostomo l'anno 1748. — in Venezia, per il Pasinello 1748 in 12 — Poesia del Silvani, e del Lalli. — Musica del Gibelli.
# EZIO. Dramma. — in Venezia, per il Bettinelli. 1733 in 4 Nel Tomo I. delle Opere Drammatiche dell'Autore divise in V. Tomi. — ed ivi, per il detto. 1752 in 12 — nel Tomo V. delle dette Opere, divise in VI. Tomi, ed in varie altre Edizioni. — . dell'Ab. Pietro Metastasio, Romano.
# FEDELTÀ, ANCHE DOPO MORTE. Tragicommedia (in prosa), ovvere, il Regnar dopo Morte. in Bologna, per gli Eredi Pisarri, 1689 in 12 — Traduzione dal Portoghese di D. Domenico Zaffi.
# FAUSTO, ovvero, il Sogno di Don Pasquale, Tragicommedia. — in Bologna. in 12 —
# FIDA PASTORELLA — in Venezia, per il Marconi, 1753 in 12 — d'Autore Anonimo.
# GALATEA. Serenata. — in Venezia, per il Bettinelli, 1733 in 4 nel Tomo III. delle Opere Drammatiche dell'Autore. — ivi, per lo stesso, 1752 in 12 — nel Tomo V. ed in molte altre Edizioni, dell'Ab. Pietro Metastasio, Romano, Poeta Cesareo. — Fu prima cantata, e stampata in Vienna nella Imperial Corte.
# GIGLIO TRASPORTATO IN CIELO. Dramma per Musica, in 12
# GIULIO CESARE IN TORINO. Dramma. in 12.
# GIUSEPPE RICONOSCIUTO. Azione Sacra. — in Venezia, per il Bettinelli. 1733 in 4 nel Tomo III. delle Opere Drammatiche dell'Autore. — ivi, per il detto. 1752 in 12 — nel Tomo VI. ed in varie altre Edizioni. — . dell'Ab. Pietro Metastasio, Romano.
# GRAN COSTANTE NELLA FEDE, ovvero, la Trionfatrice Onestà di Santa Eugenia. — Opera Sacra (in prosa). — in Bologna, per il Longhi. 1683 in 12 — di, Giambatista Ancona, Spoletino.
# GRAZIE VENDICATE. Serenata per Musica, prima cantata e stampata in Vienna d'Austria, nella Imperiale Corte. — poi in Venezia, per il Bettinelli— 1737 in 4 nel Tomo IX. delle Opere Drammatiche dell'Autore. — ivi, per il detto. 11752 in 12 — nel Tomo V. ed in varie altre Edizioni. — . dell'Ab. Pietro Metastasio, Romano, Poeta Cesareo.
# GUASCONE. Farsa (di un solo Atto in versi sciolti) in Milano, per l'Agnelli. 1740 in 12 — nel Tom. VI.
# IFIGENIA IN AULIDE. Tragedia di Euripide tradotta (in versi). — in Padova, per il Manfrè. 1749 in 8 colle altre di Euripide, ed è la Tragedia IX. col testo Greco a riscontro. dal P. Michelangiolo Carmeli.
# IFIGENIA IN TAURIS. Tragedia di Euripide tradotta (in versi). — in Padova, per il Manfrè. 1749 in 8 colle altre di Euripide, ed è la Tragedia X. col Testo Greco a riscontro, dal P. Michelangiolo Carmeli.
# ISACCO, FIGURA DEL REDENTORE. Azione Sacra per Musica, applicata al Santissimo Sepolcro. — in Venezia, per il Bettinelli, 1745 in 4 nel Tomo V. delle Opere dell'Autore. — ivi, per il detto. 1752 in 12 — nel Tomo VI. ed in altre varie Edizioni. — . dell'Abate Pietro Metastasio, Romano.
# LAMENTI D'ORFEO. Componimento Drammatico. — in Arezzo, per il Bellotti. 1754 in 4 nel Tomo I. delle Opere Drammatiche dell'Autore, dell'Ab. Gio. Claudio Pasquini, Sanese.
# MAGA FULMINATA. Dramma in Milano, per il Ramellari. 1744 in 12 — colle altre Poesie Drammatiche dell'Autore unitamente stampate.
# LUCIO PAPIRIO DITTATORE. Dramma per Musica, — in Venezia, per il Pasquali. 1744 in 8 nel Tomo I. delle Poesie Drammatiche dell'Autore divise in X. Tomi di Apostolo Zeno, Veneziano.
# MASCHERA LEVATA AL VIZIO. in Venezia, per il Voltolini. 1744 in 12 — nel Tomo IV. delle Opere Drammatiche dell'Autore divise in IV. Tomi. — . dell'Ab. Francesco Silvani, Veneziano.
# ORACOLO IN MESSENIA. Dramma per Musica rappresentato in Venezia nel Teatro di Sant'Angiolo l'anno 1738 in 12 — in Venezia, per il Buonarrigo. 1738 in 12 — Questo Dramma è tratto dalla Merope di Apostolo Zeno. — Musica di D. Antonio Vivaldi, Veneziano.
# ORAZIO. Tragedia di Pietro Cornelio tradotta (in versi). — in Venezia, per il Bertella 1747 in 4 nel Tom. II. delle Opere del Corneliada Giuseppe Baretti, Torinese, col testo Francese a riscontro.
# ORFANO RICONOSCIUTO. Commedia (in prosa). — in Venezia, per il Pasinello. 1753 in 12 — nel Tomo II. delle Commedie dell'Autore. — . dell'Ab. Pietro Chiari, Bresciano. Sono tre Commedie distinte in tre Azioni benchè dello stesso Argomento, l'una all'altra susseguenti.
# ORTI ESPERIDI. Serenata rappresentata nella Corte Imperiale a Vienna, ed ivi stampata, — ed in Venezia, per il Bettinelli, 1733 in 4 nel Tom. III. delle Opere Drammatiche dell'Autore. — ivi 1752 in 12 — ed in varie altre Edizioni. — . dell'Ab. Pietro Metastasio, Romano, Poeta Cesareo.
# PACE TRA LA VIRTÙ, E LA BELLEZZA. Componimento Drammatico che servì per trattenimento della Imperial Corte di Vienna. — in Ven. nel Tom. V. per il Bettinelli, 1733 in 4 nel Tomo V. delle Opere Drammatiche dell'Autore. — ivi, per lo stesso, 1752 in 12 — nel Tomo V. ed in molte altre Edizioni, dell'Ab. Pietro Metastasio, Romano, Poeta Cesareo.
# PADRE ACCORTO DALLA FIGLIA PRUDENTE. Commedia (in prosa). — di Doligista.
# PASTOR GELOSO. Favola Boschereccia Tragica. — in Venezia, per l'Occhi. 1744 in 8. — Dell'Abate Rota.
# PETTEGOLEZZI DELLE DONNE. Commedia Veneziana (in prosa). — in Venezia, per il Bettinelli. 175. in 8 nel Tomo V. delle Commedie dell'Autore, — in Firenze, per gli Eredi Paperini. 1755 in 8 nel Tom. X. in Pesaro, per il Gavelli. 1755 in 8 nel Tomo X. — in Bologna, per gli Eredi Pisarri. 1755. nel Tomo ..d i Polisseno Fegejo Pastor Arcade, cioè del Doctor Carlo Goldoni, Veneziano.
# PIETÀ DI SABINA. Dramma Musicale. — in Firenze, per il Vangelisti. 1698 in 12 — nel Tomo II. delle Poesie Drammatiche dell'Autore, di Gio. Andrea Moniglia.
# POLIEUTO. Tragedia di Pietro Cornelio tradotta (in versi). — in Bologna, per il Volpe 1743 in 8 dal P. D. Bonifacio Collina. —
# PORTENTOSI EFFETTI DELLA MADRE NATURA. Dramma Giocoso per Musica Trappresentato in Venezia nel Teatro di S. Samuello l'anno 1752 — in Venezia, 1752 in 8 — ivi, per il Tavernin, 1753 12 nel Tomo II. delle Opere Giocose, di Polisseno Fegejo Pastor Arcade, cioè, del Dott. Carlo Goldoni, Veneziano.
# PRINCIPE FRA GL'INFORTUNI FORTUNATO. Opera (in prosa). — in Bologna, per il Mucci. 1668 in 12 —
# POVERTÀ SOLLEVATA, ovvero, l'Invidia Abbattuta. Opera (in prosa). — in Bologna, per il Pisarri. 1726 in 12 — di Dorigista.
# PRENCIPE PIÙ REALE CHE AMANTE. Opera (in prosa). — in Bologna, per gli Eredi del Sarti. 1696 in 12 — di Dorigista.
# RE GERNANDO. Tragedia — in Venezia, per il Sarzina. 1624 in 4 - del Cav. Lodovico Rota.
# RICCO, E IL POVERO. Dramma per Musica Giocoso, rappresentato in Venezia nel Teatro di S. Mosè l'anno 1753 — in Venezia, per Modesto Fenzo, 1753 in 12— Poesia e Musica d'Incerti Autori.
# RIMA VENDICATA. Rappresentazione Satirica (in tre Atti) — in Bologna, per il Volpe— 1723 in 8 nel Tomo V. delle Opere dell'Autore.
# SALA degl'INCANTI. Opera (in prosa), — in Cremona nella Stamperia del Ferrari. 1706. in 12 — Sottoginio Manasta, cioè, Tommaso Sant'Agostini.
# RUDENTE. Commedia di Plauto tradotta (in versi). — in Venezia, per il Recurti. 1751 in 8. nel Tomo II. delle Opere dell'Autore da Monsign. Balì Gregorio Redi.
# SCUOLA DELLE DONNE. Commedia di M. Moliere tradotta (in prosa). in Lipsia, per il Gleditsch, 1698 in 12 — nel Tomo I. delle Opere del Moliere. da Niccola de.
# SEDECIA ULTIMO RE DI GIUDA. Tragedia (in versi sciolti). — in Venezia, per il Valvasense. 1751 in 8 nel Tomo I. del Teatro Ebraico, del P. Giovanni Granelli, Genovese, della Comp. di Gesù.
# SEMPLICITA NON È PER LE CORTI nelle Ridicolose Facezie di Bertoldino (in prosa)) — in Bologna, per il Pisarri, 1723 in 12 — di A.C.Z.P.A.
# SERVA AMOROSA. Commedia (in prosa). — in Firenze, per gli Eredi Paperini, 1753 in 8 nel Tomo I. delle Commedie dell'Autore. — in Bologna, per gli Eredi Pisarri. 1753 in 8 nel Tom. IV. — in Pesaro, per il Gavelli. 1753 in 12 — nel Tomo I.del Dottor Carlo Goldoni, Veneziano.
# SGANARELLO. Commedia di M. Moliere tradotta (in prosa) in Lipsia, per il Gleditsch, 1698 in 12 — nel Tomo I. delle Opere del Molier tradotta con tutte l'altre 1751 in 12 — nel Tomo V. delle Commedie dell'Autore. da Nicola de' Castelli.
# SESOSTRI. Dramma rappresentativo. in Venezia, per il Murari. in 12 — È lo stesso del Zeno, ma riformato per recitarsi. da Luigi Riccoboni, Comico.
# SOGNO DI VENERE. Cantata per Musica. — in Venezia, per il Bortoli. 1700 in 12 — con altre dell'Autore, di Girolamo Gigli, Fiorentino.
# STIAVA. Commedia (in prosa). — in Venezia, colla data di Firenze, 1750 in 8 nel Tomo I. del Teatro Comico Fioremino. — Poesia, e Prosa di Giammaria Cecchi, Fiorentino.
# STORDITO, ovvero, il Contrattempo. Commedia tradotta dal Francese di Mons. Moliere. — in Lipsia, per il Gleditsch, 1698 in 12 — nel Tomo II. delle Opere del Moliere. da Niccolò di Castelli.
# SUPPLICI. Tragedia di Euripide. in Padova, per il Manfrè, 1748 in 8 —. dal P. Michelangiolo Carmeli, con tutte le altre di Euripide col Testo Greco a riscontro.
# SURENA. Tragedia di Pietro Cornelio tradotta (in versi). — in Venezia, per il Bertella. 1748 in 4 nel Tomo III. delle Tragedie del Cornelio, col testo Francese a rincontro. da Giuseppe Baretti, Torinese.
# TESEO IN CRETA. Tragedia. — in Udine, per il Murero. 1749 in 4. del P. D. Salvador Riva Ch. Reg. di S. Paolo.
# TRE DISPERATI. Opera (in prosa) — in Modena, nella Stamperia Soliani, senz'anno. in 12 — Data in luce dagl'Incogniti.
# TRUFFALDINOE FINTO PAPAGALLO PER AMORE. Commedia (in prosa) in Venezia, per il Lovisa, senz'anno, in 12 — del Monaceni.
# VANITÀ DELUSA. Dramma per Musica rappresentato in Venezia nel Teatro di S. Mose. l'anno 1748 — in Venezia. 1748 in 12 — Poesia, e Musica d'Incerti.
# VIRTÙ VINCE L'AVARIZIA. Commedia (in prosa): — in Firenze, per il Mouke. 1734 in 12 — nel Tomo II. delle Commedie dell'Autore, di Giambatista Fagiuoli, Fiorentino.
# VICENDE D'AMOR, E DI FORTUNA. Opera (in prosa) tradotta dallo Spagnuolo. — in Modena, per il Dogni, senz'anno, in 12 — senza nome di Traduttore, il qual è però Giambatista Toschi.
# VINCISLAO. Tragedia di M. Rotrou tradotta (in prosa). — in Bologna, per il Volpe. senza Stampatore. 1725 in 12 — nel Tomo IV. delle Opere varie tradotte, e recitate in Bologna.

# %%
# debug strange stuff
unique_values = df['location'].value_counts()
sorted_values = unique_values.sort_values(ascending=False)
for value, frequency in sorted_values.items():
  #if type(value) == int and value < 1500:
  print(f"{value}: {frequency}")
# Out:
# Venezia: 1853
# Bologna: 509
# Roma: 359
# Napoli: 358
# Firenze: 352
# Vienna: 244
# Palermo: 208
# Siena: 200
# Milano: 161
# Ferrara: 93
# Viterbo: 92
# Padova: 91
# Verona: 75
# Mantova: 58
# Vicenza: 55
# Macerata: 52
# Parma: 51
# Modona: 46
# Unknown: 42
# Ronciglione: 41
# Genova: 41
# Perugia: 36
# Lucca: 33
# Brescia: 31
# Torino: 30
# Lipsia: 30
# Fiorenza: 26
# Ancona: 24
# Messina: 24
# Trevigi: 19
# Orvieto: 18
# Reggio: 17
# Cremona: 16
# Arezzo: 16
# Terni: 15
# Catania: 14
# Monaco: 14
# Udine: 14
# Urbino: 13
# Belluno: 13
# Pisa: 13
# Piazzola: 12
# Piacenza: 12
# Pavia: 11
# Parigi: 11
# Foligno: 10
# Bergamo: 10
# Pesaro: 9
# Bracciano: 9
# Todi: 8
# Serravalle: 8
# Trani: 7
# Modena: 7
# Trapani: 6
# Pratolino: 6
# Venetia: 6
# Fermo: 5
# Livorno: 5
# Cesena: 5
# Bassano: 5
# Rovigo: 5
# Faenza: 4
# Versi: 4
# Città: 4
# Colonia: 4
# Lodi: 4
# Rimini: 4
# Fano: 4
# Gubbio: 3
# Ravenna: 3
# Ascoli: 3
# Velletri: 3
# Carmagnola: 3
# Benevento: 3
# San: 3
# Grimani: 3
# Londra: 3
# lode: 3
# Commedia: 3
# fine: 3
# volgare: 3
# Volgare: 3
# Cossenza: 3
# Spoleto: 2
# Atto: 2
# Persicetto: 2
# Napoletana: 2
# di: 2
# Carpi: 2
# Roveredo: 2
# Scene): 2
# Teatro: 2
# nuovo: 2
# Guastalla: 2
# quella: 2
# Opera: 2
# Conegliano: 2
# Piazza: 2
# Scena: 2
# risposta: 2
# tempo: 2
# Trivigi: 2
# Cosenza: 2
# Dresda: 2
# segno: 2
# Adria: 2
# verse: 2
# Favola: 2
# Ispruch: 2
# Trento: 2
# Roma): 2
# istile: 2
# Lecce: 2
# Bari: 2
# Seravalle: 2
# Pistoja: 2
# Codogno: 2
# dimostrazione: 2
# Massa: 2
# vers: 2
# diverse: 2
# più: 2
# Norvegia: 1
# scena: 1
# Caprano: 1
# qualsisia: 1
# Ca: 1
# Canal: 1
# Arno: 1
# Ceneda: 1
# Lauro: 1
# Fossombrone: 1
# Lione: 1
# ottavo: 1
# essere: 1
# Spoletti: 1
# Asola: 1
# Cuneo: 1
# Nettuno: 1
# Monte: 1
# Firenz: 1
# atti: 1
# Imola: 1
# Persia: 1
# Egloghe: 1
# Taranto: 1
# Collegio: 1
# Assisi: 1
# Inglese: 1
# brosa): 1
# Este: 1
# detta: 1
# Napol: 1
# Madrid: 1
# Asolo: 1
# Cento: 1
# Venezia): 1
# Luca: 1
# Varsavia: 1
# Camerino: 1
# questa: 1
# celebrare: 1
# Tragedia: 1
# Spagna: 1
# Santo: 1
# Moglie: 1
# sostenerlo: 1
# Monneo: 1
# Canonica: 1
# Isprugg: 1
# Lintz: 1
# difesa: 1
# Sicilia: 1
# Mondovi: 1
# Castel: 1
# Spoleti: 1
# Venevia: 1
# Fabriano: 1
# Dramma: 1
# Capodistria: 1
# Ronx): 1
# gran: 1
# Corfu: 1
# Salzburgo: 1
# ogni: 1
# M: 1
# Tortona: 1
# Tropea: 1
# Napeli: 1
# Ratisbona: 1
# Pietro: 1
# Caprarola: 1
# stile: 1
# Vercelli: 1
# voto: 1
# Cagliari: 1
# allegrezza: 1
# Micro—Praga: 1
# Chieti: 1
# prose): 1
# Cinque: 1
# vario: 1
# Camera: 1
# Monac: 1
# Aman: 1
# sestine): 1
# via: 1
# Calle: 1
# Micopraga: 1
# questo: 1
# Inspruch: 1
# nuova: 1
# Egloga: 1
# Crema: 1
# Rappresentazione: 1
# sempre: 1
# Anspach: 1
# Trino: 1
# ottave: 1
# Tommaso: 1
# Osimo: 1
# Vilna: 1
# brevi: 1
# che: 1
# Peroscia: 1
# altre: 1
# sette: 1
# Como: 1
# Birba: 1
# capo: 1
# Semirilimiriminitiricontea: 1
# Francofort: 1
# Cortona: 1
# latino: 1
# Maometto: 1
# vesi: 1
# Fiera: 1
# prOsa): 1
# Treviso: 1
# Recanati: 1
# Cosmopoli: 1
# Bruselles: 1
# prisa): 1
# recitato: 1
# congiuntura: 1
# Conca: 1
# quello: 1
# compendio: 1
# Scandiano: 1
# Scipione: 1
# Favola—scenica: 1
# sua: 1
# Perosa: 1
# Murano: 1
# confidenza: 1
# Lugano: 1
# Giulia: 1
# Bolognai: 1
# Maschera: 1
# Arimino: 1
# Libertapoli: 1
# seguito: 1
# ): 1
# Venezia,per: 1
# Salerno: 1
# onoranza: 1
# Forll: 1
# Rapolano: 1
# Napole: 1
# Foggia: 1
# Jessi: 1
# London: 1
# in: 1

# %%
# find recurrent empty fields

for column in df.columns:
    none_count = df[column].apply(lambda x: x is None).sum()
    total_entries = len(df[column])
    percent_none = ((none_count / total_entries) * 100 if total_entries > 0 else 0).round(2)
    print(f"In the '{column}' column there are {none_count} None values out of {total_entries} ---> {percent_none}")
# Out:
# In the 'entry' column there are 0 None values out of 6076 ---> 0.0
# In the 'title' column there are 0 None values out of 6076 ---> 0.0
# In the 'subtitle' column there are 5750 None values out of 6076 ---> 94.63
# In the 'author' column there are 349 None values out of 6076 ---> 5.74
# In the 'genre' column there are 13 None values out of 6076 ---> 0.21
# In the 'mode' column there are 4026 None values out of 6076 ---> 66.26
# In the 'location' column there are 220 None values out of 6076 ---> 3.62
# In the 'publisher' column there are 379 None values out of 6076 ---> 6.24
# In the 'year' column there are 117 None values out of 6076 ---> 1.93
# In the 'format' column there are 246 None values out of 6076 ---> 4.05
# In the 'libretto' column there are 0 None values out of 6076 ---> 0.0
# In the 'translation' column there are 0 None values out of 6076 ---> 0.0

# %%
# export for further refining
df.to_csv("database-allacci.csv")

# %% [markdown]
# ##2. Exploratory data analysis

# %%
def visualise(info, plot_type):
    filtered_df = df[df[info].notna() & (df[info] != "Unknown")]

    # Get the top 15 entries sorted by frequency
    top_15_values = filtered_df[info].value_counts().head(15)

    # Print the top 15 values and their frequencies
    for value, frequency in top_15_values.items():
        print(f"{value}: {frequency}")

    # Create a DataFrame for the top 15 values
    top_15_df = filtered_df[filtered_df[info].isin(top_15_values.index)]

    # Sort values by frequency in descending order
    sorted_values = top_15_df[info].value_counts().index

    # Dynamically call the specified plot method
    getattr(plt, plot_type)(sorted_values, top_15_df[info].value_counts(),
                            color='darkred', edgecolor='black')

    plt.xlabel(f"{info}")
    plt.ylabel('frequency')

    # Set x-axis ticks and labels based on sorted order of frequencies
    plt.xticks(sorted_values, [f'{value}' for value in sorted_values], rotation=90, ha="right")

    plt.show()

# %%
visualise('author',plot_type="barh")
# Out:
# Apostolo Zeno: 125
# Niccolò Minato: 73
# Francesco Silvani: 72
# Pietro Metastasio: 55
# Carlo Goldoni: 46
# Matteo Noris: 40
# Ortensio Scamacca: 38
# Giacinto Andrea Cicognini: 36
# Pier Jacopo Martello: 33
# Aurelio Aurelj: 31
# Antonio Salvi: 26
# Girolamo Gigli: 26
# Arcangelo Spagna: 25
# Dottor Carlo Goldoni: 24
# Domenico Lalli: 21
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in convert_units(self, x)
#    1731         try:
# -> 1732             ret = self.converter.convert(x, self.units, self)
#    1733         except Exception as e:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/category.py in convert(value, unit, axis)
#      48         if unit is None:
# ---> 49             raise ValueError(
#      50                 'Missing category information for StrCategoryConverter; '
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# <ipython-input-48-b44573db1cf3> in <cell line: 1>()
# ----> 1 visualise('author',plot_type="barh")
#
# <ipython-input-46-2df37b331310> in visualise(info, plot_type)
#      23
#      24     # Set x-axis ticks and labels based on sorted order of frequencies
# ---> 25     plt.xticks(sorted_values, [f'{value}' for value in sorted_values], rotation=90, ha="right")
#      26
#      27     plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in xticks(ticks, labels, minor, **kwargs)
#    1884                             "without setting 'ticks'")
#    1885     else:
# -> 1886         locs = ax.set_xticks(ticks, minor=minor)
#    1887
#    1888     if labels is None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      72
#      73         def wrapper(self, *args, **kwargs):
# ---> 74             return get_method(self)(*args, **kwargs)
#      75
#      76         wrapper.__module__ = owner.__module__
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in set_ticks(self, ticks, labels, minor, **kwargs)
#    2072             raise ValueError('labels argument cannot be None when '
#    2073                              'kwargs are passed')
# -> 2074         result = self._set_tick_locations(ticks, minor=minor)
#    2075         if labels is not None:
#    2076             self.set_ticklabels(labels, minor=minor, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in _set_tick_locations(self, ticks, minor)
#    2012
#    2013         # XXX if the user changes units, the information will be lost here
# -> 2014         ticks = self.convert_units(ticks)
#    2015         locator = mticker.FixedLocator(ticks)  # validate ticks early.
#    2016         for name, axis in self.axes._axis_map.items():
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in convert_units(self, x)
#    1732             ret = self.converter.convert(x, self.units, self)
#    1733         except Exception as e:
# -> 1734             raise munits.ConversionError('Failed to convert value(s) to axis '
#    1735                                          f'units: {x!r}') from e
#    1736         return ret
#
# ConversionError: Failed to convert value(s) to axis units: Index(['Apostolo Zeno', 'Niccolò Minato', 'Francesco Silvani',
#        'Pietro Metastasio', 'Carlo Goldoni', 'Matteo Noris',
#        'Ortensio Scamacca', 'Giacinto Andrea Cicognini',
#        'Pier Jacopo Martello', 'Aurelio Aurelj', 'Antonio Salvi',
#        'Girolamo Gigli', 'Arcangelo Spagna', 'Dottor Carlo Goldoni',
#        'Domenico Lalli'],
#       dtype='object')

# %%
# plot locations

data = {'Venezia': 1814, 'Bologna': 517, 'Roma': 359, 'Napoli': 358, 'Firenze': 351,
        'Vienna': 241, 'Palermo': 208, 'Siena': 195, 'Milano': 159, 'Ferrara': 91,
        'Viterbo': 90, 'Padova': 87, 'Verona': 74, 'Mantova': 56, 'Vicenza': 55,
        'Macerata': 52, 'Parma': 49, 'Modena': 46, 'Ronciglione': 40, 'Genova': 38,
        'Lucca': 34, 'Perugia': 32, 'Brescia': 31, 'Torino': 30, 'Lipsia': 30}

# Simplified dataset of city coordinates (latitude, longitude)
city_coordinates = {
      'Venezia': (45.4408474, 12.3155151),
      'Bologna': (44.494887, 11.342616),
      'Roma': (41.9027835, 12.4963655),
      'Napoli': (40.852162, 14.2681103),
      'Firenze': (43.7695604, 11.2558136),
      'Vienna': (48.2083537, 16.3725042),
      'Palermo': (38.1157, 13.3615),
      'Siena': (43.3186, 11.3307),
      'Milano': (45.4642, 9.1900),
      'Ferrara': (44.8350, 11.6180),
      'Viterbo': (42.4174, 12.1047),
      'Padova': (45.4064, 11.8768),
      'Verona': (45.4384, 10.9916),
      'Mantova': (45.1569, 10.7910),
      'Vicenza': (45.5455, 11.5350),
      'Macerata': (43.3000, 13.4532),
      'Parma': (44.8015, 10.3279),
      'Modena': (44.6471, 10.9252),
      'Ronciglione': (42.2711, 12.1987),
      'Genova': (44.4056, 8.9463),
      'Lucca': (43.8420, 10.5027),
      'Perugia': (43.1107, 12.3890),
      'Brescia': (45.5416, 10.2118),
      'Torino': (45.0703, 7.6869),
      'Lipsia': (51.3432, 12.3809)
}

# Create a map centered around Italy
m = folium.Map(location=[41.8719, 12.5674], zoom_start=4)

# Add markers for each city with the size proportional to the number of events
for city, events in data.items():
    coordinates = city_coordinates.get(city)
    if coordinates:
        folium.CircleMarker(
            location=coordinates,
            radius=events / 50,  # Adjust the scaling factor as needed
            color='red',
            fill=True,
            fill_color='red',
            fill_opacity=0.2,
            popup=f"{city}: {events} events"
        ).add_to(m)

# Display the map in Colab
m

# %%
# print the corpus' diachronic span

filtered_df = df[df['year'].notna() & (df['year'] != "Unknown")]

# Plot histogram
plt.hist(filtered_df['year'], bins=range(1500, 1760, 10), color="darkgreen", edgecolor='black')

# Set major labels every 50 years
major_labels = range(1500, 1760, 10)
plt.xticks(major_labels, rotation=90)

# Set plot labels and title
plt.xlabel('Year')
plt.ylabel('No. of works')

# Show the plot
plt.show()

# %% [markdown]
# ## Trashbin/drafts

# %%
# after the tab is clean enough, we will generate slugs for easier work identification
'''
def generate_slug(row):
    author_words = row['author'].split() if row['author'] else ['UnknownAuthor']
    title_word = row['title'].split()[0] if row['title'] else 'UnknownTitle'

    first_word = next((word for word in author_words if len(word) >= 4), author_words[0])

    return f"{first_word}-{title_word}"

df['slug'] = df.apply(generate_slug, axis=1)
'''

# %%
'''
# Add a new column 'Length' representing the length of each entry
df['entry_length'] = df['full_entry'].apply(len)

# Filter entries with length less than 1000
df_filtered = df[df['entry_length'] < 1000]

# Create a histogram to visualize the distribution of entry lengths
plt.hist(df_filtered['entry_length'], bins=100, edgecolor='black')
plt.title('Distribution of Entry Lengths (Length < 1000)')
plt.xlabel('Length of Entries')
plt.ylabel('Frequency')
plt.show()
'''

# %%
'''
# Sort the DataFrame by the 'Length' column in descending order
df_sorted = df.sort_values(by='Length', ascending=False)

# Print the top 5 entries with the highest length
top_5_entries = df_sorted.head(5)['Full Text']
for i, entry in enumerate(top_5_entries, start=1):
    print(f"Top {i} Entry - Length {len(entry)}:\n{entry}\n{'='*50}\n")
'''
